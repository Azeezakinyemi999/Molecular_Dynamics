# %% [markdown]
# # Notebook 06b — H* Adsorption Energy + NEB Dissociation
# ## Hastelloy N | Hydrogen Interaction Study
#
# Extends NB06 by placing single H at all 171 ACAT-identified sites from `surface_sites.json` instead of 9 nominal sites.
#
# **Key differences from NB06:**
# - Site coordinates read from `surface_sites.json` (NB04b output)
# - 171 single-H jobs submitted as SLURM array (max 8 concurrent)
# - best1/best2 selection uses BOTH H-H > 2.5 A AND graph distance >= 2
# - True site labels from `identify_adsorption_site()`
# - Saves `H_site_coords.json`
# - Everything from NB06 onwards (IS/FS build, NEB, CINEB, MEP) unchanged
#
# **Requires:** NB04b and NB05b completed

# %% [markdown]
# ---
# ## 1. Theory & Background
# ---

# %% [markdown]
# ### 1.1 The Nudged Elastic Band Method
#
# The nudged elastic band (NEB) method finds the minimum energy path (MEP) between two known states on a potential energy surface [1,2]. The MEP is the lowest-energy pathway connecting the initial state (IS) to the final state (FS). The highest point on the MEP is the transition state (TS), and its energy above the IS is the activation barrier E_a.
#
# **How NEB works:**
# 1. Generate N replicas by linear interpolation (IDPP) between IS and FS
# 2. Connect adjacent replicas with spring forces (the elastic band)
# 3. Minimize all replicas simultaneously: true forces act perpendicular to the band (move replicas toward MEP); spring forces act parallel to the band (keep replicas evenly spaced). The nudging projects these components apart [1,2].
# 4. At convergence, replicas lie along the MEP
#
# **Climbing image NEB (CINEB):** After initial NEB convergence, the highest-energy replica is identified, its spring forces removed, and it is pushed uphill to the true saddle point [3]. This gives an accurate E_a.

# %% [markdown]
# ### 1.2 The Dissociation Reaction
#
# We compute the MEP for:
#
# H₂* (bridge) → H* + H* (hollow sites)
#
# **Initial state (IS):** H₂ at the most stable site — most stable molecular adsorption site from Notebook 05 (E_ads (eV)).
#
# **Final state (FS):** Two separate H atoms at their optimal hollow sites, found by individual H atom minimizations .
#
# | Quantity | Symbol | Definition |
# |---------|--------|------------|
# | Activation barrier | E_a | E(TS) − E(IS) |
# | Reaction energy | ΔE | E(FS) − E(IS) |
#
# If E_a ≈ 0: H₂ dissociates barrierlessly. If ΔE < 0: dissociation is exothermic.
#
# **Key references:** [1,2,4,5]

# %% [markdown]
# ### 1.3 Finding the Final State — Option B
#
# We cannot assume both H atoms sit at FCC hollows — on an alloy surface optimal sites depend on local composition [4,5,6].
#
# **Option B protocol:**
# 1. Place one H atom at each candidate site (FCC hollow, HCP hollow, top-Ni, bridge) on the clean slab
# 2. Minimize each independently — gives E_ads(H*) at each site
# 3. The two most stable non-adjacent sites form the NEB final state
# 4. Place 2 H atoms at these sites and minimize — this is the FS
#
# **Why non-adjacent?** Two H atoms at adjacent sites repel each other through the surface. The final state must have H atoms separated by at least one lattice spacing [4,5].
#
# **H atom reference energy:** E_ads(H*) = E(slab+H) − E(clean_slab) − 0.5×E(H₂_gas). The 0.5 factor comes from H₂ → 2H*, so each H costs half the H₂ energy [4,5].
#
# **Key references:** [4,5,6]

# %% [markdown]
# ---
# ## 2. Execution Strategy
# ---

# %% [markdown]
# ### What We Are Doing in This Notebook
#
# ```
# 3.1  Imports, parameters
#        — read ALL previous results from logs, no hardcoding
# 3.2  Build individual H atom structures (7 sites) + submit
# 3.3  Parse H atom jobs — find most stable single-H sites
# 3.4  Build NEB IS and FS + submit FS minimization
#        IS: H2* at bridge (NB05 physisorbed minimum)
#        FS: 2H* at local hollows flanking bridge (minimized)
# 3.5  Verify IS and FS — geometry checks, energies
# 3.6  (removed — merged into 3.5)
# 3.7  Write ASE CINEB script (IDPP interpolation, 1 A100)
# 3.8  Submit NEB job
# 3.9  Parse NEB results — E_a, delta_E, path
# 3.10 Plot MEP
# 3.11 Decision cell
# ```

# %% [markdown]
# --- ## 2. Execution Strategy ---
#
# ### What We Are Doing in This Notebook
#
# ```
# 3.1  Imports, parameters
#        — read ALL previous results from logs
#        — load 171 ACAT sites from surface_sites.json
#        — build surface graph for graph distance calculation
# 3.2  Build 171 single-H structures + submit SLURM array
# 3.3  Parse H atom jobs — rank all 171 sites by E_ads(H*)
#        — update SITE_COORDS with relaxed H positions
#        — pick best1 and best2 using H-H > 2.5 A AND graph distance >= 2
#        — true site identification with identify_adsorption_site()
#        — save H_site_coords.json
# 3.4  Build NEB IS and FS + submit FS minimization
# 3.5  Verify IS and FS
# 3.7  Write ASE CINEB script
# 3.8  Submit NEB job
# 3.9  Parse NEB results
# 3.10 Plot MEP
# 3.11 Decision cell
# ```

# %% [markdown]
# --- ## 3. Code ---
#
# ### 3.1 — Imports, Parameters & Read All Previous Results

# %%
import numpy as np
import os
import json
import subprocess
import shutil
import matplotlib.pyplot as plt
from ase.io import read
from collections import Counter
from itertools import combinations
import warnings
warnings.filterwarnings('ignore')

import ase
print(f'ASE version : {ase.__version__}')
print(f'NumPy       : {np.__version__}')



# ═══════════════════════════════════════════════════════════
# YOUR SYSTEM PATHS
# ═══════════════════════════════════════════════════════════
LAMMPS_CMD        = '/projects/westgroup/akinyemi.az/mace_lammps/lammps/build-mliap/lmp'
MACE_MODEL_LAMMPS = '/projects/westgroup/akinyemi.az/mace_lammps/models/mace-mp-0b2-medium.model-mliap_lammps.pt'
MACE_MODEL_ASE    = '/projects/westgroup/akinyemi.az/mace_lammps/models/mace-mp-0b2-medium.model'
MACE_MODEL        = MACE_MODEL_LAMMPS  # default for LAMMPS scripts
KOKKOS_FLAGS      = ['-k', 'on', 'g', '1', '-sf', 'kk',
                     '-pk', 'kokkos', 'newton', 'on', 'neigh', 'half']
SLURM_CONFIG = {
    'partition'     : 'gpu',
    'ntasks'        : 1,
    'cpus_per_task' : 8,
    'gpu'           : 'a100:1',
    'time'          : '06:00:00',
    'conda_env'     : 'mace-lammps',
    'cuda_version'  : '12.3.0',
    'openmpi_ver'   : '4.1.6',
    'ld_paths'      : [
        '/shared/EL9/explorer/cuda/12.3.0/lib64/stubs',
        '/projects/westgroup/akinyemi.az/mace_lammps/lammps/build-mliap',
        '/home/akinyemi.az/miniforge3/envs/mace-lammps/lib',
    ]
}

# ── Atom type mapping ────────────────────────────────────────
ELEM_STR    = 'Al B C Cr Fe Mo Ni H'
PAIR_STYLE  = 'mliap unified'
PAIR_SUFFIX = '0'
E2T = {'Al':1, 'B':2, 'C':3, 'Cr':4, 'Fe':5, 'Mo':6, 'Ni':7, 'H':8}
MASSES = {
    1:(26.9815,'Al'), 2:(10.8110,'B'),  3:(12.0110,'C'),
    4:(51.9961,'Cr'), 5:(55.8450,'Fe'), 6:(95.9600,'Mo'),
    7:(58.6934,'Ni'), 8:( 1.0080,'H'),
}

# ── NEB parameters ───────────────────────────────────────────
N_REPLICAS   = 18       # intermediate images
SPRING_CONST = 2.0     # eV/Å²
NEB_FTOL     = 0.05    # eV/Å — NEB convergence
N1_STEPS     = 5000    # phase 1: regular NEB steps
NEB_STEPS    = 10000    # phase 2: CINEB steps

# ── Geometry constants ───────────────────────────────────────
Z_FREEZE_CUTOFF = 22.115  # Å — frozen layer cutoff (NB04)
H_ATOM_HEIGHT   = 1.5     # Å above surface for single H atom
NN_CUTOFF       = 3.2     # Å — nearest-neighbor cutoff

# ── Minimization settings ────────────────────────────────────
ETOL    = 0
FTOL    = 1e-6
MAXITER = 10000
MAXEVAL = 100000

# ── File paths ───────────────────────────────────────────────
#SLAB_RELAXED = 'structures/notebook04/hastelloy_n_slab_relaxed.lammps'
# CORRECT — same slab NB08 used
SLAB_RELAXED = 'structures/notebook05-adsorption-energy/7/clean_slab_reminimized.lammps'
NEB_IS_FILE  = 'structures/notebook06-Neb-dissociation/7/neb_initial.lammps'
NEB_LOG      = 'results/notebook06-Neb-dissociation/7/neb.log'
NEB_PATH_OUT = 'results/notebook06-Neb-dissociation/7/neb_path.dat'
# H_ATOM_SITES = site_data['h_atom_sites']
# print(f'H_ATOM_SITES loaded from NB05: {H_ATOM_SITES}')

for d in ['structures/notebook06-Neb-dissociation/7', 'results/notebook06-Neb-dissociation/7',
          'lammps_scripts/notebook06-Neb-dissociation/7', 'slurm_scripts/notebook06-Neb-dissociation/7']:
    os.makedirs(d, exist_ok=True)

# ── Helper: parse energy log ──────────────────────────────────
def parse_energy_log(logfile):
    results = {}
    if not os.path.exists(logfile):
        return None
    with open(logfile) as f:
        for line in f:
            line = line.strip()
            for key in ['pe_final_eV', 'fmax_eV_per_Ang', 'natoms']:
                if key in line and ':' in line:
                    try:
                        results[key] = float(line.split(':')[1].strip())
                    except:
                        pass
    return results if results else None

# ═══════════════════════════════════════════════════════════
# READ ALL PREVIOUS RESULTS FROM LOGS — NO HARDCODING
# ═══════════════════════════════════════════════════════════
print('Reading previous notebook results from logs...')
print()

# NB05: E_clean_slab
res = parse_energy_log('results/notebook05-adsorption-energy/7/ads_clean_slab.log')
if res:
    E_CLEAN_SLAB = res['pe_final_eV']
    print(f'E_clean_slab  : {E_CLEAN_SLAB:.6f} eV  [ads_clean_slab.log]')
else:
    raise FileNotFoundError('results/notebook05-adsorption-energy/7/ads_clean_slab.log not found.')

# NB05: E_H2_gas
res = parse_energy_log('results/notebook05-adsorption-energy/7/ads_h2_gas.log')
if res:
    E_H2_GAS = res['pe_final_eV']
    print(f'E_H2_gas      : {E_H2_GAS:.6f} eV  [ads_h2_gas.log]')
else:
    raise FileNotFoundError('results/notebook05-adsorption-energy/7/ads_h2_gas.log not found.')

# NB05: E_IS — most stable adsorption site
E_IS = None
E_ADS_best = 0.0  # least stable possible
best_site_log = None

for site_log in ['ads_bridge.log', 'ads_top_cr.log', 'ads_top_ni.log', 'ads_top_fe.log',
                 'ads_top_b.log', 'ads_top_c.log', 'ads_top_mo.log',
                 'ads_fcc_hollow.log', 'ads_hcp_hollow.log']:
    res = parse_energy_log(f'results/notebook05-adsorption-energy/7/{site_log}')
    if res:
        E_IS_candidates = res['pe_final_eV']
        E_ads_cand = E_IS_candidates - E_CLEAN_SLAB - E_H2_GAS
        if E_ads_cand < E_ADS_best:
            E_ADS_best    = E_ads_cand
            E_IS          = E_IS_candidates
            best_site_log = site_log

if E_IS is None:
    raise FileNotFoundError('No NB05 adsorption log found.')

print(f'E_IS (most stable): {E_IS:.6f} eV  [{best_site_log}]')
print(f'E_ads              : {E_ADS_best:.4f} eV')

# ── Load relaxed slab ─────────────────────────────────────────
# with open('results/notebook05-adsorption-energy/7/site_coords.json') as f:
#     site_data = json.load(f)

# z_surf       = site_data['z_surf']
# z_H2         = site_data['z_H2']
# min_dist     = site_data['min_dist']
# SITE_COORDS  = {k: tuple(v) for k, v in site_data['site_coords'].items()}
# H_ATOM_SITES = site_data['h_atom_sites']

# print('Site coordinates loaded from NB05:')
# for name, (x, y) in SITE_COORDS.items():
#     print(f'  {name:12s}: ({x:.4f}, {y:.4f})')
# print(f'H_ATOM_SITES : {H_ATOM_SITES}')
# print(f'z_surf = {z_surf:.4f} Å  |  z_H_atom = {z_surf + H_ATOM_HEIGHT:.4f} Å')

with open(f'results/notebook05-adsorption-energy/7/site_coords.json') as f:
    site_data = json.load(f)

z_surf       = site_data['z_surf']
z_H2         = site_data['z_H2']
min_dist     = site_data['min_dist']
H_ATOM_SITES = site_data['h_atom_sites']

# Use relaxed H positions if available, fall back to nominal
if 'site_coords_relaxed' in site_data:
    SITE_COORDS = {k: tuple(v) for k, v in site_data['site_coords_relaxed'].items()}
    print('SITE_COORDS loaded from relaxed H positions (NB05 post-relaxation):')
else:
    SITE_COORDS = {k: tuple(v) for k, v in site_data['site_coords'].items()}
    print('SITE_COORDS loaded from nominal placement (NB05 pre-relaxation):')

# Also load relaxed labels for reporting
RELAXED_LABELS = site_data.get('site_labels_relaxed', {})

for name, (x, y) in SITE_COORDS.items():
    rlbl = RELAXED_LABELS.get(name, name)
    match = '' if rlbl in name or name in rlbl else f'  ← placed as {name}, relaxed to {rlbl}'
    print(f'  {name:12s}: ({x:.4f}, {y:.4f}){match}')

# ── write_min_frozen helper ───────────────────────────────────
def write_min_frozen(job_name, input_file, output_file):
    lines = [
        'units metal', 'atom_style atomic', 'newton on', 'boundary p p f', '',
        f'read_data      {input_file}', '',
        f'pair_style     {PAIR_STYLE} {MACE_MODEL} {PAIR_SUFFIX}',
        f'pair_coeff     * * {ELEM_STR}', '',
        'neighbor       2.0 bin', 'neigh_modify   every 1 delay 0 check yes', '',
        f'region         frozen_reg  block  INF INF  INF INF  EDGE  {Z_FREEZE_CUTOFF}',
        'group          frozen_atoms  region  frozen_reg',
        'group          free_atoms    subtract  all  frozen_atoms',
        'fix            freeze  frozen_atoms  setforce  0.0  0.0  0.0', '',
        'thermo         50', 'thermo_style   custom step pe fmax', '',
        f'minimize       {ETOL}  {FTOL}  {MAXITER}  {MAXEVAL}', '',
        'variable  pe_final  equal  pe',
        'variable  fmax_f    equal  fmax',
        'variable  natoms    equal  atoms', '',
        'print "ENERGY_RESULTS_START"',
        f'print "  job_name         : {job_name}"',
        'print "  pe_final_eV      : ${pe_final}"',
        'print "  fmax_eV_per_Ang  : ${fmax_f}"',
        'print "  natoms           : ${natoms}"',
        'print "ENERGY_RESULTS_END"', '',
        f'write_data     {output_file}',
    ]
    script = '\n'.join(lines) + '\n'
    path = f'lammps_scripts/notebook06-Neb-dissociation/7/min_{job_name}.lammps'
    with open(path, 'w') as f:
        f.write(script)
    return path

# ── NB06b specific paths ──────────────────────────────────────
SURFACE_SITES_JSON = 'results/notebook04b-surface-relaxation/7/surface_sites.json'

for d in [
    'structures/notebook06b-Neb-dissociation/7',
    'results/notebook06b-Neb-dissociation/7',
    'lammps_scripts/notebook06b-Neb-dissociation/7',
    'slurm_scripts/notebook06b-Neb-dissociation/7',
]:
    os.makedirs(d, exist_ok=True)

NEB_IS_FILE  = 'structures/notebook06b-Neb-dissociation/7/neb_initial.lammps'
NEB_LOG      = 'results/notebook06b-Neb-dissociation/7/neb.log'
NEB_PATH_OUT = 'results/notebook06b-Neb-dissociation/7/neb_path.dat'

# ── Project 2 modules ─────────────────────────────────────────
import sys
sys.path.append('Project2_surface_labeling')
try:
    from models.site_identifier import identify_adsorption_site
    from models.surface_graph import build_surface_graph, get_site_neighbors
    print('Project 2 modules loaded')
except ImportError:
    print('WARNING: models.site_identifier or models.surface_graph not found')

# ── Load surface_sites.json ───────────────────────────────────
if not os.path.exists(SURFACE_SITES_JSON):
    raise FileNotFoundError(f'{SURFACE_SITES_JSON} not found. Complete NB04b first.')

with open(SURFACE_SITES_JSON) as f:
    surface_data = json.load(f)

sites_list = surface_data['sites']
SITE_IDS   = [s['site_id'] for s in sites_list]
SITE_COORDS = {s['site_id']: (s['level1']['position'][0],
                               s['level1']['position'][1])
               for s in sites_list}

print(f'Loaded {len(SITE_IDS)} ACAT sites from surface_sites.json')

# ── Build surface graph for graph distance calculation ────────
SLAB_FOR_ACAT = 'structures/notebook05-adsorption-energy/7/clean_slab_reminimized.lammps'
if os.path.exists(SLAB_FOR_ACAT):
    print('Building surface graph for graph distance...')
    G_surf, _, _, _ = build_surface_graph(SLAB_FOR_ACAT, seed=7)
    print(f'  Graph: {G_surf.number_of_nodes()} nodes, {G_surf.number_of_edges()} edges')
else:
    G_surf = None
    print('WARNING: SLAB_FOR_ACAT not found — graph distance check disabled')

# ── Read previous results ─────────────────────────────────────
print('\nReading previous notebook results from logs...')

res = parse_energy_log('results/notebook05b-adsorption-energy/7/ads_clean_slab.log')
if res:
    E_CLEAN_SLAB = res['pe_final_eV']
    print(f'E_clean_slab  : {E_CLEAN_SLAB:.6f} eV')
else:
    raise FileNotFoundError('ads_clean_slab.log not found. Complete NB05b first.')

res = parse_energy_log('results/notebook05b-adsorption-energy/7/ads_h2_gas.log')
if res:
    E_H2_GAS = res['pe_final_eV']
    print(f'E_H2_gas      : {E_H2_GAS:.6f} eV')
else:
    raise FileNotFoundError('ads_h2_gas.log not found. Complete NB05b first.')

# Best IS from NB05b
NB05B_BEST_IS = 'structures/notebook05b-adsorption-energy/7/best_adsorption_site.lammps'
if not os.path.exists(NB05B_BEST_IS):
    raise FileNotFoundError(f'{NB05B_BEST_IS} not found. Complete NB05b first.')

# Read E_IS from NB05b H2_site_coords.json
h2_json = 'results/notebook05b-adsorption-energy/7/H2_site_coords.json'
if os.path.exists(h2_json):
    with open(h2_json) as f:
        h2_data = json.load(f)
    best_is_id = h2_data.get('best_is')
    E_IS_site  = h2_data['sites'].get(best_is_id, {}) if best_is_id else {}
    E_IS_energy = h2_data['sites'][best_is_id]['E_ads_eV'] if best_is_id else None
    print(f'Best IS       : {best_is_id}  ({E_IS_site.get("true_label","?")})')

# Load SLAB_RELAXED for H atom placement
# SLAB_RELAXED = 'structures/notebook04-surface-relaxation/7/hastelloy_7_slab_relaxed.lammps'
slab_for_h = read(SLAB_RELAXED, format='lammps-data', style='atomic')
pos_h   = slab_for_h.get_positions()
z_surf  = pos_h[:, 2].max()
z_H_atom = z_surf + H_ATOM_HEIGHT
L_h     = slab_for_h.cell.lengths()

print(f'z_surf        : {z_surf:.4f} A')
print(f'H atom height : {z_H_atom:.4f} A')
# Out:
# ASE version : 3.27.0
# NumPy       : 2.4.3
# Reading previous notebook results from logs...
#
# E_clean_slab  : -2390.925227 eV  [ads_clean_slab.log]
# E_H2_gas      : -6.790499 eV  [ads_h2_gas.log]
# E_IS (most stable): -2398.201099 eV  [ads_top_b.log]
# E_ads              : -0.4854 eV
# SITE_COORDS loaded from relaxed H positions (NB05 post-relaxation):
#   top_ni      : (4.3867, 2.6209)
#   top_mo      : (4.0492, 6.6579)
#   top_cr      : (10.0548, 3.7332)
#   top_fe      : (10.3595, 0.2752)
#   top_c       : (10.0761, 9.1138)  ← placed as top_c, relaxed to top_ni
#   top_b       : (6.4476, 10.7798)  ← placed as top_b, relaxed to top_mo
#   bridge      : (10.0692, 9.1222)  ← placed as bridge, relaxed to top_ni
#   fcc_hollow  : (5.1130, 2.6292)  ← placed as fcc_hollow, relaxed to bridge
#   hcp_hollow  : (6.4053, 2.4248)  ← placed as hcp_hollow, relaxed to top_ni
# Project 2 modules loaded
# Loaded 171 ACAT sites from surface_sites.json
# Building surface graph for graph distance...
# Reading slab...
#   360 atoms  cell=[12.448 12.936 52.36 ]
#   Top layer: 30 atoms  comp={np.str_('Ni'): 22, np.str_('Fe'): 1, np.str_('Cr'): 1, np.str_('Mo'): 4, np.str_('C'): 1, np.str_('B'): 1}
# Running ACAT...
#   n_layers used for ACAT  : 3
#   171 valid sites
#   Atom nodes: 30  Atom-atom edges: 88
#   Site nodes: 171  Site-atom: 367  Site-site: 1904
#   Total nodes: 201  Total edges: 2359
#   Graph: 201 nodes, 2359 edges
#
# Reading previous notebook results from logs...
# E_clean_slab  : -2390.925227 eV
# E_H2_gas      : -6.790499 eV
# Best IS       : s_123  (Ni_atop_physisorbed)
# z_surf        : 38.1241 A
# H atom height : 39.6241 A

# %% [markdown]
# ### 3.2 — Build 171 Single-H Structures and Submit SLURM Array
#
# > Places one H atom at each of the 171 ACAT site positions and submits as a SLURM array job (max 8 concurrent).

# %%
# Cell 3.2 — Build 171 single-H structures + SLURM array
kk = ' '.join(KOKKOS_FLAGS)
sc = SLURM_CONFIG
ld = '\n'.join('export LD_LIBRARY_PATH=' + p + ':$LD_LIBRARY_PATH'
                 for p in sc['ld_paths'])
cwd = os.getcwd()

def write_slab_h_atom_b(site_id, x_site, y_site):
    outfile  = f'structures/notebook06b-Neb-dissociation/7/h_atom_{site_id}.lammps'
    all_syms = slab_for_h.get_chemical_symbols() + ['H']
    h_pos    = np.array([x_site % L_h[0], y_site % L_h[1], z_H_atom])
    all_pos  = np.vstack([slab_for_h.get_positions(), h_pos])
    with open(outfile, 'w') as f:
        f.write(f'# Hastelloy N + H at {site_id} — NB06b\n\n')
        f.write(f'{len(all_syms)} atoms\n{len(MASSES)} atom types\n\n')
        f.write(f'0.0  {L_h[0]:.10f}  xlo xhi\n')
        f.write(f'0.0  {L_h[1]:.10f}  ylo yhi\n')
        f.write(f'0.0  {L_h[2]:.10f}  zlo zhi\n\n')
        f.write('Masses\n\n')
        for t, (m, el) in MASSES.items():
            f.write(f'{t}  {m}  # {el}\n')
        f.write('\nAtoms # atomic\n\n')
        for i, (sym, p) in enumerate(zip(all_syms, all_pos), 1):
            f.write(f'{i}  {E2T[sym]}  {p[0]:.10f}  {p[1]:.10f}  {p[2]:.10f}\n')
    return outfile

def write_min_frozen_b(job_name, input_file, output_file):
    lines = [
        'units metal', 'atom_style atomic', 'newton on', 'boundary p p f', '',
        f'read_data      {input_file}', '',
        f'pair_style     {PAIR_STYLE} {MACE_MODEL} {PAIR_SUFFIX}',
        f'pair_coeff     * * {ELEM_STR}', '',
        'neighbor       2.0 bin', 'neigh_modify   every 1 delay 0 check yes', '',
        f'region         frozen_reg  block  INF INF  INF INF  EDGE  {Z_FREEZE_CUTOFF}',
        'group          frozen_atoms  region  frozen_reg',
        'group          free_atoms    subtract  all  frozen_atoms',
        'fix            freeze  frozen_atoms  setforce  0.0  0.0  0.0', '',
        'thermo         50', 'thermo_style   custom step pe fmax', '',
        f'minimize       {ETOL}  {FTOL}  {MAXITER}  {MAXEVAL}', '',
        'variable  pe_final  equal  pe',
        'variable  fmax_f    equal  fmax', '',
        'print "ENERGY_RESULTS_START"',
        f'print "  job_name         : {job_name}"',
        'print "  pe_final_eV      : ${pe_final}"',
        'print "  fmax_eV_per_Ang  : ${fmax_f}"',
        'print "ENERGY_RESULTS_END"', '',
        f'write_data     {output_file}',
    ]
    path = f'lammps_scripts/notebook06b-Neb-dissociation/7/min_{job_name}.lammps'
    with open(path, 'w') as f:
        f.write('\n'.join(lines) + '\n')
    return path

# Build all structures and scripts
print(f'Building {len(SITE_IDS)} single-H structures...')
script_paths_h = {}
for sid in SITE_IDS:
    x, y = SITE_COORDS[sid]
    struct = write_slab_h_atom_b(sid, x, y)
    script_paths_h[sid] = write_min_frozen_b(
        f'h_atom_{sid}', struct,
        f'structures/notebook06b-Neb-dissociation/7/h_atom_{sid}_relaxed.lammps')
print(f'Done. {len(script_paths_h)} structures and scripts written.')

# Site index file
index_file = 'slurm_scripts/notebook06b-Neb-dissociation/7/site_index.txt'
with open(index_file, 'w') as f:
    f.write('\n'.join(SITE_IDS) + '\n')

# Array SLURM script
arr = ['#!/bin/bash']
arr += ['#SBATCH --job-name=nb06b_h']
arr += [f'#SBATCH --ntasks={sc["ntasks"]}']
arr += [f'#SBATCH --cpus-per-task={sc["cpus_per_task"]}']
arr += [f'#SBATCH --gres=gpu:{sc["gpu"]}']
arr += [f'#SBATCH --partition={sc["partition"]}']
arr += ['#SBATCH --time=01:00:00']
arr += ['#SBATCH --array=0-170%8']
arr += ['#SBATCH --output=results/notebook06b-Neb-dissociation/7/slurm_%A_%a.out']
arr += ['', f'module load OpenMPI/{sc["openmpi_ver"]}']
arr += [f'module load cuda/{sc["cuda_version"]}']
arr += ['', 'source ~/miniforge3/etc/profile.d/conda.sh']
arr += [f'conda activate {sc["conda_env"]}']
arr += ['', ld, '', f'cd {cwd}', '']
arr += [f'SITE_ID=$(sed -n "$((SLURM_ARRAY_TASK_ID + 1))p" {index_file})']
arr += ['echo "Task $SLURM_ARRAY_TASK_ID: $SITE_ID"', '']
arr += [f'{LAMMPS_CMD} {kk} \\']
arr += ['    -in lammps_scripts/notebook06b-Neb-dissociation/7/min_h_atom_${SITE_ID}.lammps \\']
arr += ['    -log results/notebook06b-Neb-dissociation/7/h_atom_${SITE_ID}.log', '']
arr += ['echo "Done: $SITE_ID $(date)"']

array_path = 'slurm_scripts/notebook06b-Neb-dissociation/7/run_array.sh'
with open(array_path, 'w') as f:
    f.write('\n'.join(arr) + '\n')
os.chmod(array_path, 0o755)


print()
print(f'Files written:')
print(f'  Array script    : {array_path}')

print()
print('Next step: run auto_submit_nb056.sh from the project root')
print('  chmod +x auto_submit_nb06b.sh')
print('  nohup bash auto_submit_nb06b.sh > nb05b_submit.log 2>&1 &')
print('  tail -f nb05b_submit.log')
print()
print('After ALL jobs finish, run cell 3.3.')
# Out:
# Building 171 single-H structures...
# Done. 171 structures and scripts written.
#
# Files written:
#   Array script    : slurm_scripts/notebook06b-Neb-dissociation/7/run_array.sh
#
# Next step: run auto_submit_nb056.sh from the project root
#   chmod +x auto_submit_nb06b.sh
#   nohup bash auto_submit_nb06b.sh > nb05b_submit.log 2>&1 &
#   tail -f nb05b_submit.log
#
# After ALL jobs finish, run cell 3.3.

# %% [markdown]
# ### 3.3 — Parse H Atom Jobs, Rank, and Pick best1/best2
#
# > Run after all SLURM jobs finish.
#
# Picks best1 and best2 using **both criteria**:
# - H-H separation > 2.5 Å (physical distance)
# - Graph distance >= 2 (sites do not share a surface atom)

# %%
# Cell 3.3 — Parse, rank, update coords, pick best1/best2
h_energies = {}
h_eads     = {}
missing    = []

print('Single H atom adsorption energies')
print('E_ads(H*) = E(slab+H) - E(clean_slab) - 0.5*E(H2_gas)')
print('=' * 65)

for sid in SITE_IDS:
    log = f'results/notebook06b-Neb-dissociation/7/h_atom_{sid}.log'
    res = parse_energy_log(log)
    if res and 'pe_final_eV' in res:
        h_energies[sid] = res['pe_final_eV']
        h_eads[sid]     = h_energies[sid] - E_CLEAN_SLAB - 0.5*E_H2_GAS
    else:
        missing.append(sid)

if missing:
    print(f'WARNING: {len(missing)} logs not found. Wait for jobs to finish.')
    print(f'Missing: {missing[:5]}{"..." if len(missing)>5 else ""}')
else:
    print(f'All {len(SITE_IDS)} logs parsed.')

# Rank
ranked = sorted(h_eads, key=h_eads.get)
print()
print(f'Top 10 sites by E_ads(H*):')
print(f'  {"Site":10s}  {"E_ads (eV)":>12s}  {"Label"}')
print('  ' + '-' * 55)
for sid in ranked[:10]:
    label = next((s['level1']['full_label']
                  for s in sites_list if s['site_id'] == sid), '')
    print(f'  {sid:10s}  {h_eads[sid]:12.4f}  {label}')

# Update SITE_COORDS with relaxed H positions
print('\nUpdating SITE_COORDS from relaxed structures...')
for sid in SITE_IDS:
    rpath = f'structures/notebook06b-Neb-dissociation/7/h_atom_{sid}_relaxed.lammps'
    if not os.path.exists(rpath): continue
    slab_r = read(rpath, format='lammps-data', style='atomic')
    syms_r = np.array(slab_r.get_chemical_symbols())
    hpos   = slab_r.get_positions()[syms_r == 'H']
    if len(hpos) == 1:
        old = SITE_COORDS[sid]
        SITE_COORDS[sid] = (hpos[0][0], hpos[0][1])
        drift = np.sqrt((hpos[0][0]-old[0])**2 + (hpos[0][1]-old[1])**2)
        if drift > 0.3:
            label = next((s['level1']['full_label']
                          for s in sites_list if s['site_id'] == sid), '')
            print(f'  {sid:10s}  drift={drift:.3f} A  ({label})')

# Helper: graph distance between two site nodes
def graph_distance(G, node1, node2):
    """Shortest path via site-site edges."""
    import networkx as nx
    site_graph = nx.Graph()
    for u, v, d in G.edges(data=True):
        if d['edge_type'] == 'site-site':
            site_graph.add_edge(u, v)
    try:
        return nx.shortest_path_length(site_graph, node1, node2)
    except Exception:
        return -1   # disconnected

# Helper: find nearest site node in G for a given xy position
def find_site_node(G, xy, site_type=None):
    best_node, best_dist = None, float('inf')
    for n, d in G.nodes(data=True):
        if d.get('node_type') != 'site': continue
        if site_type and d.get('site_type') != site_type: continue
        dist = np.sqrt((d['x']-xy[0])**2 + (d['y']-xy[1])**2)
        if dist < best_dist:
            best_dist, best_node = dist, n
    return best_node, best_dist

# Pick best1 and best2 — H-H > 2.5 A AND graph distance >= 2
H_SEP_THRESHOLD   = 2.5
GRAPH_DIST_MIN    = 2

best1       = ranked[0]
x1, y1      = SITE_COORDS[best1]
best2       = None
sep2        = None
gdist2      = None

print(f'\nbest1: {best1}  E_ads={h_eads[best1]:.4f} eV  xy=({x1:.4f},{y1:.4f})')
print(f'Searching best2 (H-H > {H_SEP_THRESHOLD} A AND graph dist >= {GRAPH_DIST_MIN})...')

# Find graph node for best1
node1, _ = find_site_node(G_surf, (x1, y1)) if G_surf else (None, None)

for candidate in ranked[1:]:
    x2, y2 = SITE_COORDS[candidate]
    sep = np.sqrt((x1-x2)**2 + (y1-y2)**2)

    # Check 1: physical separation
    if sep <= H_SEP_THRESHOLD:
        print(f'  Skip {candidate}: H-H={sep:.3f} A (< {H_SEP_THRESHOLD} A)')
        continue

    # Check 2: graph distance
    node2, _ = find_site_node(G_surf, (x2, y2)) if G_surf else (None, None)
    if G_surf and node1 and node2:
        gdist = graph_distance(G_surf, node1, node2)
        if gdist >= 0 and gdist < GRAPH_DIST_MIN:
            label = next((s['level1']['full_label']
                          for s in sites_list if s['site_id'] == candidate), '')
            print(f'  Skip {candidate}: graph dist={gdist} (< {GRAPH_DIST_MIN})  ({label})')
            continue
        gdist2 = gdist
    else:
        gdist2 = -1  # graph not available

    best2, sep2 = candidate, sep
    break

if best2 is None:
    raise RuntimeError(
        f'No valid second H site found with H-H > {H_SEP_THRESHOLD} A '
        f'AND graph dist >= {GRAPH_DIST_MIN}. '
        'Lower thresholds or check SITE_IDS.')

x2, y2 = SITE_COORDS[best2]
label1 = next((s['level1']['full_label']
               for s in sites_list if s['site_id'] == best1), best1)
label2 = next((s['level1']['full_label']
               for s in sites_list if s['site_id'] == best2), best2)

print()
print(f'FS site 1 : {best1:10s}  E_ads={h_eads[best1]:.4f} eV  '
      f'label={label1}')
print(f'FS site 2 : {best2:10s}  E_ads={h_eads[best2]:.4f} eV  '
      f'label={label2}')
print(f'H-H separation   : {sep2:.4f} A')
print(f'Graph distance   : {gdist2}  '
      f'({"ok" if gdist2 >= GRAPH_DIST_MIN else "graph unavailable"})')
print()
print('Run cell 3.3b to identify true site labels.')
# Out:
# Single H atom adsorption energies
# E_ads(H*) = E(slab+H) - E(clean_slab) - 0.5*E(H2_gas)
# =================================================================
# WARNING: 1 logs not found. Wait for jobs to finish.
# Missing: ['s_33']
#
# Top 10 sites by E_ads(H*):
#   Site          E_ads (eV)  Label
#   -------------------------------------------------------
#   s_127            -0.8783  MoMo_bridge
#   s_135            -0.8783  MoNi_bridge
#   s_154            -0.8783  Ni_atop
#   s_128            -0.8783  MoMoNi_hollow_fcc
#   s_131            -0.8783  MoNi_bridge
#   s_118            -0.8074  Ni_atop
#   s_119            -0.8074  MoNi_bridge
#   s_120            -0.8074  MoMoNi_hollow_fcc
#   s_122            -0.8074  NiNiNi_hollow_fcc
#   s_123            -0.8074  NiNi_bridge
#
# Updating SITE_COORDS from relaxed structures...
#   s_0         drift=1.787 A  (MoNi_bridge)
#   s_1         drift=1.832 A  (Ni_atop)
#   s_2         drift=2.232 A  (NiNi_bridge)
#   s_3         drift=1.729 A  (FeNiNi_hollow_fcc)
#   s_4         drift=1.634 A  (NiNiNi_hollow_fcc)
#   s_5         drift=1.884 A  (NiNi_bridge)
#   s_6         drift=2.998 A  (NiNiNi_hollow_fcc)
#   s_7         drift=1.503 A  (NiNiNi_hollow_fcc)
#   s_8         drift=2.187 A  (NiNi_bridge)
#   s_9         drift=2.523 A  (NiNi_bridge)
#   s_10        drift=2.454 A  (BNiNi_hollow_fcc)
#   s_11        drift=2.443 A  (BNi_bridge)
#   s_12        drift=0.397 A  (BNi_bridge)
#   s_13        drift=1.142 A  (Ni_atop)
#   s_14        drift=0.717 A  (NiNi_bridge)
#   s_16        drift=0.346 A  (NiNiNi_hollow_fcc)
#   s_17        drift=0.692 A  (FeNi_bridge)
#   s_19        drift=0.534 A  (NiNi_bridge)
#   s_20        drift=0.344 A  (NiNiNi_hollow_fcc)
#   s_21        drift=0.399 A  (NiNi_bridge)
#   s_22        drift=0.486 A  (NiNi_bridge)
#   s_23        drift=2.006 A  (Ni_atop)
#   s_24        drift=0.739 A  (NiNi_bridge)
#   s_26        drift=0.462 A  (NiNiNi_hollow_fcc)
#   s_27        drift=0.895 A  (NiNi_bridge)
#   s_29        drift=0.735 A  (NiNi_bridge)
#   s_30        drift=0.646 A  (NiNi_bridge)
#   s_32        drift=0.788 A  (NiNi_bridge)
#   s_34        drift=0.857 A  (NiNi_bridge)
#   s_37        drift=0.752 A  (NiNi_bridge)
#   s_39        drift=0.541 A  (NiNi_bridge)
#   s_40        drift=0.647 A  (NiNi_bridge)
#   s_42        drift=0.850 A  (MoNi_bridge)
#   s_43        drift=1.482 A  (Ni_atop)
#   s_44        drift=0.776 A  (FeNi_bridge)
#   s_46        drift=1.363 A  (BFeNi_hollow_fcc)
#   s_47        drift=0.760 A  (NiNi_bridge)
#   s_49        drift=0.837 A  (NiNi_bridge)
#   s_50        drift=0.798 A  (MoNi_bridge)
#   s_51        drift=1.380 A  (BMoNi_hollow_fcc)
#   s_52        drift=1.805 A  (BNi_bridge)
#   s_53        drift=1.136 A  (Fe_atop)
#   s_54        drift=0.509 A  (FeNi_bridge)
#   s_56        drift=0.469 A  (FeNi_bridge)
#   s_57        drift=1.651 A  (BFe_bridge)
#   s_58        drift=1.405 A  (Ni_atop)
#   s_59        drift=0.529 A  (NiNi_bridge)
#   s_61        drift=0.587 A  (NiNi_bridge)
#   s_63        drift=0.762 A  (NiNi_bridge)
#   s_65        drift=0.593 A  (NiNi_bridge)
#   s_66        drift=1.323 A  (Ni_atop)
#   s_67        drift=0.591 A  (NiNi_bridge)
#   s_69        drift=0.906 A  (NiNi_bridge)
#   s_71        drift=0.671 A  (NiNi_bridge)
#   s_72        drift=1.306 A  (Ni_atop)
#   s_73        drift=0.803 A  (NiNi_bridge)
#   s_75        drift=1.817 A  (NiNi_bridge)
#   s_76        drift=1.362 A  (NiNiNi_hollow_fcc)
#   s_77        drift=0.721 A  (NiNi_bridge)
#   s_78        drift=1.455 A  (Ni_atop)
#   s_79        drift=0.574 A  (NiNi_bridge)
#   s_81        drift=0.577 A  (NiNi_bridge)
#   s_83        drift=0.821 A  (CrNi_bridge)
#   s_84        drift=1.236 A  (Ni_atop)
#   s_85        drift=0.582 A  (NiNi_bridge)
#   s_87        drift=0.701 A  (CrNi_bridge)
#   s_88        drift=1.545 A  (Ni_atop)
#   s_89        drift=0.746 A  (NiNi_bridge)
#   s_91        drift=0.950 A  (CrNi_bridge)
#   s_93        drift=0.777 A  (NiNi_bridge)
#   s_94        drift=0.320 A  (NiNiNi_hollow_fcc)
#   s_95        drift=0.694 A  (NiNi_bridge)
#   s_96        drift=1.910 A  (Ni_atop)
#   s_97        drift=0.572 A  (NiNi_bridge)
#   s_99        drift=1.017 A  (NiNi_bridge)
#   s_100       drift=0.481 A  (MoNiNi_hollow_fcc)
#   s_101       drift=1.057 A  (MoNi_bridge)
#   s_102       drift=1.277 A  (Ni_atop)
#   s_103       drift=0.641 A  (NiNi_bridge)
#   s_105       drift=0.781 A  (MoNi_bridge)
#   s_107       drift=0.629 A  (MoNi_bridge)
#   s_108       drift=1.384 A  (Ni_atop)
#   s_109       drift=0.753 A  (CrNi_bridge)
#   s_111       drift=0.897 A  (MoNi_bridge)
#   s_113       drift=0.422 A  (NiNi_bridge)
#   s_114       drift=1.441 A  (Cr_atop)
#   s_115       drift=0.845 A  (CrNi_bridge)
#   s_117       drift=0.529 A  (CrNi_bridge)
#   s_118       drift=1.387 A  (Ni_atop)
#   s_119       drift=0.785 A  (MoNi_bridge)
#   s_121       drift=0.737 A  (NiNi_bridge)
#   s_122       drift=2.463 A  (NiNiNi_hollow_fcc)
#   s_123       drift=2.002 A  (NiNi_bridge)
#   s_124       drift=1.522 A  (MoNiNi_hollow_fcc)
#   s_125       drift=0.711 A  (MoNi_bridge)
#   s_126       drift=1.510 A  (Mo_atop)
#   s_127       drift=0.832 A  (MoMo_bridge)
#   s_129       drift=0.682 A  (MoMo_bridge)
#   s_131       drift=0.701 A  (MoNi_bridge)
#   s_132       drift=1.607 A  (Mo_atop)
#   s_133       drift=0.874 A  (MoNi_bridge)
#   s_135       drift=0.729 A  (MoNi_bridge)
#   s_137       drift=0.874 A  (MoNi_bridge)
#   s_138       drift=1.349 A  (Ni_atop)
#   s_139       drift=0.691 A  (NiNi_bridge)
#   s_140       drift=0.547 A  (NiNi_bridge)
#   s_141       drift=0.655 A  (NiNi_bridge)
#   s_142       drift=1.048 A  (Ni_atop)
#   s_143       drift=2.149 A  (NiNi_bridge)
#   s_144       drift=1.377 A  (Ni_atop)
#   s_145       drift=0.659 A  (MoNi_bridge)
#   s_147       drift=0.622 A  (NiNi_bridge)
#   s_148       drift=1.450 A  (Mo_atop)
#   s_149       drift=0.711 A  (MoNi_bridge)
#   s_151       drift=0.794 A  (MoNi_bridge)
#   s_153       drift=0.545 A  (MoNi_bridge)
#   s_154       drift=1.301 A  (Ni_atop)
#   s_156       drift=0.389 A  (MoNiNi_hollow_fcc)
#   s_157       drift=0.631 A  (NiNi_bridge)
#   s_159       drift=0.798 A  (MoNi_bridge)
#   s_160       drift=1.411 A  (Ni_atop)
#   s_161       drift=0.862 A  (MoNi_bridge)
#   s_162       drift=1.491 A  (BMoNi_hollow_fcc)
#   s_163       drift=1.861 A  (BNi_bridge)
#   s_164       drift=1.396 A  (Ni_atop)
#   s_165       drift=0.757 A  (MoNi_bridge)
#   s_166       drift=0.853 A  (NiNi_bridge)
#   s_167       drift=1.554 A  (Mo_atop)
#   s_168       drift=1.759 A  (BMo_bridge)
#   s_169       drift=0.878 A  (B_atop)
#   s_170       drift=1.699 A  (Ni_atop)
#
# best1: s_127  E_ads=-0.8783 eV  xy=(5.2169,7.3893)
# Searching best2 (H-H > 2.5 A AND graph dist >= 2)...
#   Skip s_135: H-H=0.000 A (< 2.5 A)
#   Skip s_154: H-H=0.000 A (< 2.5 A)
#   Skip s_128: H-H=0.000 A (< 2.5 A)
#   Skip s_131: H-H=0.000 A (< 2.5 A)
#   Skip s_118: graph dist=1 (< 2)  (Ni_atop)
#   Skip s_119: graph dist=1 (< 2)  (MoNi_bridge)
#   Skip s_120: graph dist=1 (< 2)  (MoMoNi_hollow_fcc)
#   Skip s_122: graph dist=1 (< 2)  (NiNiNi_hollow_fcc)
#   Skip s_123: graph dist=1 (< 2)  (NiNi_bridge)
#   Skip s_124: graph dist=1 (< 2)  (MoNiNi_hollow_fcc)
#   Skip s_125: graph dist=1 (< 2)  (MoNi_bridge)
#   Skip s_129: graph dist=1 (< 2)  (MoMo_bridge)
#   Skip s_148: graph dist=1 (< 2)  (Mo_atop)
#   Skip s_126: H-H=1.390 A (< 2.5 A)
#   Skip s_130: H-H=1.390 A (< 2.5 A)
#   Skip s_149: H-H=1.390 A (< 2.5 A)
#   Skip s_102: H-H=1.699 A (< 2.5 A)
#   Skip s_105: H-H=1.699 A (< 2.5 A)
#   Skip s_106: H-H=1.699 A (< 2.5 A)
#   Skip s_107: H-H=1.699 A (< 2.5 A)
#   Skip s_132: H-H=1.699 A (< 2.5 A)
#
# FS site 1 : s_127       E_ads=-0.8783 eV  label=MoMo_bridge
# FS site 2 : s_143       E_ads=-0.5860 eV  label=NiNi_bridge
# H-H separation   : 8.8683 A
# Graph distance   : 3  (ok)
#
# Run cell 3.3b to identify true site labels.

# %% [markdown]
# ### 3.3b — True Site Identification and Save `H_site_coords.json`
#
# > Runs `identify_adsorption_site()` on all 171 relaxed structures.
# > Saves `H_site_coords.json` to NB06b results path.

# %%
# Cell 3.3b — True site identification + save H_site_coords.json
h_true_sites = {}

print('True site identification (chemisorbed H*)')
print(f'  {"Site":10s}  {"True label":35s}  {"Neighbors"}')
print('  ' + '-' * 75)

for sid in SITE_IDS:
    rpath = f'structures/notebook06b-Neb-dissociation/7/h_atom_{sid}_relaxed.lammps'
    if not os.path.exists(rpath): continue
    try:
        result = identify_adsorption_site(rpath, adsorbate='H', mode='auto')
        s  = result[0]
        nn = [{'element': e, 'distance': round(d, 4), 'index': int(i)}
              for e, d, i in s['neighbors']]
        h_true_sites[sid] = {
            'site_id'        : sid,
            'true_label'     : s['label'],
            'composition'    : s['composition'],
            'mode'           : s['mode'],
            'site_type'      : s['site_type'],
            'hollow_type'    : s.get('hollow_type') or '',
            'subsurf_element': s.get('subsurf_element') or '',
            'z_above_surface': round(s.get('z_above_surface', 0.0), 4),
            'E_ads_eV'       : round(h_eads.get(sid, float('nan')), 6),
            'neighbors'      : nn,
        }
        nn_str = '  '.join(f'{e}({d:.2f}A)' for e, d, i in s['neighbors'])
        print(f'  {sid:10s}  {s["label"]:35s}  [{nn_str}]')
    except Exception as e:
        print(f'  {sid:10s}  ERROR: {e}')

# Report true labels for FS pair
true1 = h_true_sites.get(best1, {}).get('true_label', 'unknown')
true2 = h_true_sites.get(best2, {}).get('true_label', 'unknown')
print()
print(f'FS site 1 : {best1:10s}  true={true1}')
print(f'FS site 2 : {best2:10s}  true={true2}')
print(f'H-H separation : {sep2:.4f} A')
print(f'Graph distance : {gdist2}')

# Save H_site_coords.json
h_output = {
    'seed'             : 7,
    'adsorbate'        : 'H',
    'best1'            : best1,
    'best2'            : best2,
    'best1_true_label' : true1,
    'best2_true_label' : true2,
    'H_H_separation_A' : round(sep2, 4),
    'graph_distance'   : gdist2,
    'sites'            : h_true_sites,
}
h_json = 'results/notebook06b-Neb-dissociation/7/H_site_coords.json'
with open(h_json, 'w') as f:
    json.dump(h_output, f, indent=2)
print(f'\nSaved: {h_json}')
print('Run cell 3.4.')
# Out:
# True site identification (chemisorbed H*)
#   Site        True label                           Neighbors
#   ---------------------------------------------------------------------------
#   s_0         CNiNi_atop                           [Ni(1.89A)  C(3.59A)  Ni(3.70A)]
#   s_1         CNiNi_bridge                         [Ni(1.84A)  Ni(1.93A)  C(2.91A)]
#   s_2         BCNi_unknown                         [C(3.63A)  B(3.67A)  Ni(3.91A)]
#   s_3         BCNi_unknown                         [C(3.63A)  B(3.67A)  Ni(3.91A)]
#   s_4         CNiNi_atop                           [Ni(1.78A)  Ni(4.40A)  C(4.78A)]
#   s_5         MoNiNi_hollow_hcp                    [Ni(1.73A)  Ni(1.79A)  Mo(1.90A)]
#   s_6         CNiNi_atop                           [Ni(1.89A)  C(3.59A)  Ni(3.70A)]
#   s_7         MoNiNi_hollow_hcp                    [Ni(1.73A)  Ni(1.79A)  Mo(1.90A)]
#   s_8         CNiNi_atop                           [Ni(1.89A)  C(3.59A)  Ni(3.70A)]
#   s_9         MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.91A)  Mo(1.91A)]
#   s_10        MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.91A)  Mo(1.91A)]
#   s_11        BCNi_unknown                         [C(3.63A)  B(3.67A)  Ni(3.91A)]
#   s_12        BNiNi_hollow_4fold                   [B(1.31A)  Ni(1.82A)  Ni(1.83A)]
#   s_13        CNiNi_atop                           [Ni(1.78A)  Ni(4.40A)  C(4.78A)]
#   s_14        NiNiNi_bridge                        [Ni(1.68A)  Ni(1.90A)  Ni(3.08A)]
#   s_15        NiNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.73A)  Ni(1.76A)]
#   s_16        MoNiNi_unknown                       [Ni(3.42A)  Ni(4.05A)  Mo(4.15A)]
#   s_17        BCNi_unknown                         [C(3.63A)  B(3.67A)  Ni(3.91A)]
#   s_18        FeNiNi_hollow_hcp                    [Ni(1.76A)  Fe(1.81A)  Ni(2.78A)]
#   s_19        NiNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.73A)  Ni(1.76A)]
#   s_20        NiNiNi_bridge                        [Ni(1.67A)  Ni(2.05A)  Ni(3.05A)]
#   s_21        FeNiNi_atop                          [Ni(1.65A)  Fe(3.01A)  Ni(3.56A)]
#   s_22        MoNiNi_unknown                       [Ni(3.42A)  Ni(4.05A)  Mo(4.15A)]
#   s_23        NiNiNi_bridge                        [Ni(1.62A)  Ni(2.19A)  Ni(3.30A)]
#   s_24        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.70A)  Ni(1.77A)]
#   s_25        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.70A)  Ni(1.77A)]
#   s_26        MoNiNi_bridge                        [Ni(1.67A)  Mo(2.77A)  Ni(3.67A)]
#   s_27        NiNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.71A)  Ni(1.78A)]
#   s_28        NiNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.71A)  Ni(1.78A)]
#   s_29        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.70A)  Ni(1.77A)]
#   s_30        MoMoNi_atop                          [Ni(1.69A)  Mo(3.14A)  Mo(3.19A)]
#   s_31        MoMoNi_atop                          [Ni(1.69A)  Mo(3.14A)  Mo(3.19A)]
#   s_32        MoMoNi_atop                          [Ni(1.69A)  Mo(3.14A)  Mo(3.19A)]
#   s_34        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.70A)  Ni(1.75A)]
#   s_35        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.70A)  Ni(1.75A)]
#   s_36        BMoNi_atop                           [Mo(1.96A)  B(2.97A)  Ni(3.19A)]
#   s_37        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.70A)  Ni(1.77A)]
#   s_38        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.71A)  Ni(1.77A)]
#   s_39        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.70A)  Ni(1.75A)]
#   s_40        MoNiNi_bridge                        [Ni(1.75A)  Mo(1.93A)  Ni(3.11A)]
#   s_41        MoNiNi_bridge                        [Ni(1.75A)  Mo(1.93A)  Ni(3.11A)]
#   s_42        MoNiNi_bridge                        [Ni(1.75A)  Mo(1.93A)  Ni(3.11A)]
#   s_43        NiNiNi_bridge                        [Ni(1.74A)  Ni(1.81A)  Ni(3.23A)]
#   s_44        FeNiNi_hollow_hcp                    [Ni(1.72A)  Ni(1.75A)  Fe(1.81A)]
#   s_45        FeNiNi_hollow_hcp                    [Ni(1.72A)  Ni(1.75A)  Fe(1.81A)]
#   s_46        BCMo_unknown                         [B(2.94A)  C(3.51A)  Mo(4.00A)]
#   s_47        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.70A)  Ni(1.75A)]
#   s_48        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.71A)  Ni(1.73A)]
#   s_49        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.71A)  Ni(1.73A)]
#   s_50        BMoNi_atop                           [Mo(1.96A)  B(2.97A)  Ni(3.19A)]
#   s_51        BMoNi_atop                           [Mo(1.96A)  B(2.97A)  Ni(3.19A)]
#   s_52        BMoNi_atop                           [Mo(1.96A)  B(2.97A)  Ni(3.19A)]
#   s_53        BCMo_unknown                         [B(2.94A)  C(3.51A)  Mo(4.00A)]
#   s_54        FeNiNi_hollow_hcp                    [Ni(1.72A)  Ni(1.75A)  Fe(1.81A)]
#   s_55        FeNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.73A)  Fe(1.83A)]
#   s_56        FeNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.73A)  Fe(1.83A)]
#   s_57        BCMo_unknown                         [B(2.94A)  C(3.51A)  Mo(4.00A)]
#   s_58        NiNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.71A)  Ni(1.78A)]
#   s_59        NiNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.71A)  Ni(1.78A)]
#   s_60        NiNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.70A)  Ni(1.76A)]
#   s_61        NiNiNi_bridge                        [Ni(1.67A)  Ni(1.73A)  Ni(3.10A)]
#   s_62        NiNiNi_bridge                        [Ni(1.67A)  Ni(1.73A)  Ni(3.10A)]
#   s_63        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.69A)  Ni(1.76A)]
#   s_64        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.69A)  Ni(1.76A)]
#   s_65        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.69A)  Ni(1.76A)]
#   s_66        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.70A)  Ni(1.77A)]
#   s_67        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.71A)  Ni(1.77A)]
#   s_68        NiNiNi_hollow_hcp                    [Ni(1.70A)  Ni(1.72A)  Ni(1.72A)]
#   s_69        NiNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.71A)  Ni(1.76A)]
#   s_70        NiNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.71A)  Ni(1.76A)]
#   s_71        NiNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.71A)  Ni(1.76A)]
#   s_72        NiNiNi_hollow_hcp                    [Ni(1.69A)  Ni(1.70A)  Ni(1.75A)]
#   s_73        NiNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.68A)  Ni(1.72A)]
#   s_74        NiNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.68A)  Ni(1.72A)]
#   s_75        MoNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Mo(1.91A)]
#   s_76        MoNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Mo(1.91A)]
#   s_77        NiNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.68A)  Ni(1.72A)]
#   s_78        FeNiNi_hollow_hcp                    [Ni(1.72A)  Ni(1.75A)  Fe(1.81A)]
#   s_79        CrNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.73A)  Cr(1.86A)]
#   s_80        CrNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.73A)  Cr(1.86A)]
#   s_81        CrNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Cr(1.84A)]
#   s_82        CrNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Cr(1.84A)]
#   s_83        CrNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Cr(1.84A)]
#   s_84        CrNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.73A)  Cr(1.86A)]
#   s_85        CrNiNi_bridge                        [Ni(1.72A)  Cr(1.88A)  Ni(3.02A)]
#   s_86        CrNiNi_bridge                        [Ni(1.72A)  Cr(1.88A)  Ni(3.02A)]
#   s_87        CrNiNi_bridge                        [Ni(1.72A)  Cr(1.88A)  Ni(3.02A)]
#   s_88        NiNiNi_atop                          [Ni(1.68A)  Ni(2.89A)  Ni(3.55A)]
#   s_89        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.69A)  Ni(1.73A)]
#   s_90        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.69A)  Ni(1.73A)]
#   s_91        CrNiNi_bridge                        [Ni(1.75A)  Cr(1.80A)  Ni(2.86A)]
#   s_92        CrNiNi_bridge                        [Ni(1.75A)  Cr(1.80A)  Ni(2.86A)]
#   s_93        NiNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.69A)  Ni(1.73A)]
#   s_94        NiNiNi_bridge                        [Ni(1.62A)  Ni(1.77A)  Ni(3.03A)]
#   s_95        CrNiNi_bridge                        [Ni(1.75A)  Cr(1.80A)  Ni(2.86A)]
#   s_96        MoNiNi_hollow_hcp                    [Ni(1.65A)  Mo(1.89A)  Ni(2.24A)]
#   s_97        MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.80A)  Mo(1.91A)]
#   s_98        MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.80A)  Mo(1.91A)]
#   s_99        MoNiNi_hollow_hcp                    [Ni(1.65A)  Mo(1.89A)  Ni(2.24A)]
#   s_100       MoNiNi_hollow_hcp                    [Ni(1.65A)  Mo(1.89A)  Ni(2.24A)]
#   s_101       MoNiNi_hollow_hcp                    [Ni(1.65A)  Mo(1.89A)  Ni(2.24A)]
#   s_102       MoMoNi_hollow_hcp                    [Ni(1.74A)  Mo(1.93A)  Mo(1.95A)]
#   s_103       MoNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Mo(1.91A)]
#   s_104       MoNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Mo(1.91A)]
#   s_105       MoMoNi_hollow_hcp                    [Ni(1.74A)  Mo(1.93A)  Mo(1.95A)]
#   s_106       MoMoNi_hollow_hcp                    [Ni(1.74A)  Mo(1.93A)  Mo(1.95A)]
#   s_107       MoMoNi_hollow_hcp                    [Ni(1.74A)  Mo(1.93A)  Mo(1.95A)]
#   s_108       CrNiNi_hollow_hcp                    [Ni(1.66A)  Ni(1.70A)  Cr(1.95A)]
#   s_109       CrNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Cr(1.84A)]
#   s_110       CrNiNi_hollow_hcp                    [Ni(1.66A)  Ni(1.70A)  Cr(1.95A)]
#   s_111       MoNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.77A)  Mo(1.91A)]
#   s_112       MoNiNi_hollow_4fold                  [Ni(1.66A)  Ni(1.74A)  Mo(2.00A)]
#   s_113       CrNiNi_hollow_hcp                    [Ni(1.66A)  Ni(1.70A)  Cr(1.95A)]
#   s_114       CrNiNi_hollow_4fold                  [Ni(1.66A)  Cr(1.73A)  Ni(2.15A)]
#   s_115       CrNiNi_hollow_hcp                    [Ni(1.66A)  Ni(1.70A)  Cr(1.95A)]
#   s_116       CrNiNi_hollow_4fold                  [Ni(1.66A)  Cr(1.73A)  Ni(2.15A)]
#   s_117       CrNiNi_bridge                        [Ni(1.75A)  Cr(1.80A)  Ni(2.86A)]
#   s_118       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_119       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_120       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_121       NiNiNi_bridge                        [Ni(1.62A)  Ni(1.77A)  Ni(3.03A)]
#   s_122       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_123       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_124       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_125       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_126       MoMoNi_hollow_hcp                    [Ni(1.77A)  Mo(1.90A)  Mo(2.00A)]
#   s_127       MoMoNi_hollow_hcp                    [Ni(1.73A)  Mo(1.92A)  Mo(1.96A)]
#   s_128       MoMoNi_hollow_hcp                    [Ni(1.73A)  Mo(1.92A)  Mo(1.96A)]
#   s_129       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_130       MoMoNi_hollow_hcp                    [Ni(1.77A)  Mo(1.90A)  Mo(2.00A)]
#   s_131       MoMoNi_hollow_hcp                    [Ni(1.73A)  Mo(1.92A)  Mo(1.96A)]
#   s_132       MoMoNi_hollow_hcp                    [Ni(1.74A)  Mo(1.93A)  Mo(1.95A)]
#   s_133       MoNiNi_hollow_4fold                  [Ni(1.66A)  Ni(1.74A)  Mo(2.00A)]
#   s_134       MoNiNi_hollow_hcp                    [Ni(1.73A)  Ni(1.79A)  Mo(1.90A)]
#   s_135       MoMoNi_hollow_hcp                    [Ni(1.73A)  Mo(1.92A)  Mo(1.96A)]
#   s_136       MoNiNi_hollow_4fold                  [Ni(1.74A)  Ni(1.77A)  Mo(1.92A)]
#   s_137       MoNiNi_hollow_4fold                  [Ni(1.74A)  Ni(1.77A)  Mo(1.92A)]
#   s_138       CrNiNi_hollow_hcp                    [Ni(1.66A)  Ni(1.70A)  Cr(1.95A)]
#   s_139       CrNiNi_hollow_4fold                  [Ni(1.66A)  Cr(1.73A)  Ni(2.15A)]
#   s_140       CNiNi_hollow_hcp                     [Ni(1.64A)  Ni(1.79A)  C(2.25A)]
#   s_141       MoNiNi_hollow_hcp                    [Ni(1.73A)  Ni(1.79A)  Mo(1.90A)]
#   s_142       CrNiNi_bridge                        [Ni(1.75A)  Cr(1.80A)  Ni(2.86A)]
#   s_143       CNiNi_unknown                        [Ni(3.36A)  Ni(3.37A)  C(4.33A)]
#   s_144       CNiNi_atop                           [Ni(1.89A)  C(3.59A)  Ni(3.70A)]
#   s_145       MoNiNi_bridge                        [Ni(1.67A)  Mo(1.94A)  Ni(3.04A)]
#   s_146       MoNiNi_bridge                        [Ni(1.67A)  Mo(1.94A)  Ni(3.04A)]
#   s_147       MoNiNi_bridge                        [Ni(1.67A)  Mo(1.94A)  Ni(3.04A)]
#   s_148       MoMoNi_hollow_hcp                    [Ni(1.75A)  Mo(1.94A)  Mo(1.95A)]
#   s_149       MoMoNi_hollow_hcp                    [Ni(1.77A)  Mo(1.90A)  Mo(2.00A)]
#   s_150       MoNiNi_hollow_hcp                    [Ni(1.71A)  Ni(1.79A)  Mo(1.91A)]
#   s_151       MoNiNi_bridge                        [Mo(1.88A)  Ni(1.90A)  Ni(3.23A)]
#   s_152       MoNiNi_bridge                        [Mo(1.88A)  Ni(1.90A)  Ni(3.23A)]
#   s_153       MoNiNi_bridge                        [Mo(1.88A)  Ni(1.90A)  Ni(3.23A)]
#   s_154       MoMoNi_hollow_hcp                    [Ni(1.73A)  Mo(1.92A)  Mo(1.96A)]
#   s_155       MoNiNi_hollow_4fold                  [Ni(1.73A)  Ni(1.76A)  Mo(1.99A)]
#   s_156       MoNiNi_hollow_4fold                  [Ni(1.73A)  Ni(1.76A)  Mo(1.99A)]
#   s_157       MoNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.73A)  Mo(1.92A)]
#   s_158       MoNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.73A)  Mo(1.92A)]
#   s_159       MoNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.73A)  Mo(1.92A)]
#   s_160       MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.91A)  Mo(1.91A)]
#   s_161       MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.91A)  Mo(1.91A)]
#   s_162       MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.91A)  Mo(1.91A)]
#   s_163       MoNiNi_hollow_hcp                    [Ni(1.67A)  Ni(1.91A)  Mo(1.91A)]
#   s_164       MoNiNi_hollow_hcp                    [Ni(1.68A)  Ni(1.73A)  Mo(1.92A)]
#   s_165       MoNiNi_bridge                        [Ni(1.75A)  Mo(1.93A)  Ni(3.11A)]
#   s_166       MoNiNi_bridge                        [Mo(1.88A)  Ni(1.90A)  Ni(3.23A)]
#   s_167       MoNiNi_bridge                        [Ni(1.77A)  Mo(1.93A)  Ni(3.15A)]
#   s_168       BMoNi_atop                           [Mo(1.96A)  B(2.97A)  Ni(3.19A)]
#   s_169       BCMo_bridge                          [B(1.35A)  C(2.46A)  Mo(2.86A)]
#   s_170       MoNiNi_bridge                        [Ni(1.67A)  Mo(1.94A)  Ni(3.04A)]
#
# FS site 1 : s_127       true=MoMoNi_hollow_hcp
# FS site 2 : s_143       true=CNiNi_unknown
# H-H separation : 8.8683 A
# Graph distance : 3
#
# Saved: results/notebook06b-Neb-dissociation/7/H_site_coords.json
# Run cell 3.4.

# %% [markdown]
# ### 3.3c — Plot E_ads(H*) for All 171 Sites
#
# > Bar chart colored by site type. FS pair highlighted.

# %%
# Cell 3.3c — Plot E_ads for all 171 sites
if not h_eads:
    print('No data to plot. Run cell 3.3 first.')
else:
    COLOR_MAP = {'ontop': '#E8782A', 'bridge': '#378ADD',
                 'hollow': '#1D9E75', 'hollow_4fold': '#9B59B6'}
    fs_pair = {best1, best2}

    labels_p = list(ranked)
    eads_p   = [h_eads[s] for s in labels_p]
    site_labels_p = [
        next((si['level1']['full_label']
              for si in sites_list if si['site_id'] == s), s)
        for s in labels_p]
    colors_p = [
        COLOR_MAP.get(
            next((si['level1']['site_type']
                  for si in sites_list if si['site_id'] == s), 'bridge'),
            '#888888')
        for s in labels_p]
    ec_p = ['black' if s in fs_pair else 'none' for s in labels_p]
    lw_p = [2.0     if s in fs_pair else 0.0   for s in labels_p]

    fig, ax = plt.subplots(figsize=(max(14, len(labels_p)*0.12), 5))
    ax.bar(range(len(labels_p)), eads_p,
           color=colors_p, edgecolor=ec_p,
           linewidth=lw_p, alpha=0.85)
    ax.axhline(0, color='black', lw=0.8, ls='--')
    ax.set_xticks(range(len(labels_p)))
    ax.set_xticklabels(site_labels_p, rotation=90, fontsize=4)
    ax.set_xlabel('Site', fontsize=11)
    ax.set_ylabel('E_ads(H*) (eV)', fontsize=11)
    ax.set_title('H* Adsorption Energy — All 171 ACAT Sites (Seed 7)', fontsize=12)
    from matplotlib.patches import Patch
    ax.legend(handles=[Patch(facecolor=v, label=k)
                       for k, v in COLOR_MAP.items()], fontsize=8)
    plt.tight_layout()
    plt.savefig('results/notebook06b-Neb-dissociation/7/eads_h_all_sites.png',
                dpi=150, bbox_inches='tight')
    plt.show()
    print('Saved: results/notebook06b-Neb-dissociation/7/eads_h_all_sites.png')
# Out:
# Saved: results/notebook06b-Neb-dissociation/7/eads_h_all_sites.png

# %% [markdown]
# ### 3.4 — Build NEB Initial and Final States + Submit FS Minimization

# %%
# ─────────────────────────────────────────────────────────────
# IS: H2* at most stable NB05 adsorption site (best_adsorption_site.lammps)
# FS: 2H* at best1 and best2 from cell 3.3
#     — most stable non-adjacent single-H sites from explicit minimization
#     — H-H separation enforced > 2.5 A (fully dissociated criterion)
# FS is minimized with LAMMPS before the NEB runs.
# ─────────────────────────────────────────────────────────────

sc = SLURM_CONFIG
kk = ' '.join(KOKKOS_FLAGS)
ld = '\n'.join(f'export LD_LIBRARY_PATH={p}:$LD_LIBRARY_PATH' for p in sc['ld_paths'])

# ── IS: strip Velocities from NB05 best site relaxed structure ──
src_is = 'structures/notebook05b-adsorption-energy/7/best_adsorption_site.lammps'
if not os.path.exists(src_is):
    raise FileNotFoundError(f'{src_is} not found. Complete Notebook 05 first.')


sep_final =sep2
with open(src_is) as f:
    content = f.read()
if 'Velocities' in content:
    content = content[:content.index('Velocities')].rstrip() + '\n'
    print('Stripped Velocities from IS')
with open(NEB_IS_FILE, 'w') as f:
    f.write(content)
print(f'NEB IS written : {NEB_IS_FILE}')

# ── Read IS geometry ──────────────────────────────────────────
is_atoms     = read(NEB_IS_FILE, format='lammps-data', style='atomic')
is_pos       = is_atoms.get_positions()
is_syms      = np.array(is_atoms.get_chemical_symbols())
h_is         = is_pos[is_syms == 'H']
h2_center_xy = h_is[:, :2].mean(axis=0)
z_surf_is    = is_pos[is_syms != 'H', 2].max()
z_H2_actual  = h_is[:, 2].mean() - z_surf_is
cell         = is_atoms.cell.diagonal()

print(f'IS site           : {best_site_log}')
print(f'IS H2 center xy   : ({h2_center_xy[0]:.4f}, {h2_center_xy[1]:.4f})')
print(f'IS H2 height      : {z_H2_actual:+.4f} A above z_surf')
print(f'IS H-H dist       : {np.linalg.norm(h_is[0]-h_is[1]):.4f} A')

# ── FS: place H atoms at best1 and best2 from cell 3.3 ───────
x1, y1 = SITE_COORDS[best1]
x2, y2 = SITE_COORDS[best2]
z_fs   = z_surf_is + H_ATOM_HEIGHT

h1_fs = np.array([x1 % cell[0], y1 % cell[1], z_fs])
h2_fs = np.array([x2 % cell[0], y2 % cell[1], z_fs])

# Displacement of each H from IS center to FS site
d1 = np.linalg.norm(h_is[0, :2] - h1_fs[:2])
d2 = np.linalg.norm(h_is[1, :2] - h2_fs[:2])

print(f'\nFS site 1 : {best1:12s}  xy=({h1_fs[0]:.4f}, {h1_fs[1]:.4f})  disp={d1:.4f} A')
print(f'FS site 2 : {best2:12s}  xy=({h2_fs[0]:.4f}, {h2_fs[1]:.4f})  disp={d2:.4f} A')
print(f'H-H separation    : {sep_final:.4f} A')

# ── Build FS raw file ─────────────────────────────────────────
NEB_FS_RAW      = 'structures/notebook06b-Neb-dissociation/7/neb_final_raw.lammps'
FS_RELAXED_DATA = 'structures/notebook06b-Neb-dissociation/7/neb_final_relaxed.lammps'

metal_pos   = is_pos[is_syms != 'H']
metal_syms  = is_syms[is_syms != 'H']
fs_all_pos  = np.vstack([metal_pos, h1_fs, h2_fs])
fs_all_syms = np.concatenate([metal_syms, ['H', 'H']])

with open(NEB_FS_RAW, 'w') as f:
    f.write(f'# NEB FS: 2H* at {best1} + {best2} — Notebook 06\n\n')
    f.write(f'{len(fs_all_pos)} atoms\n8 atom types\n\n')
    f.write(f'0.0 {cell[0]:.10f} xlo xhi\n')
    f.write(f'0.0 {cell[1]:.10f} ylo yhi\n')
    f.write(f'0.0 {cell[2]:.10f} zlo zhi\n\n')
    f.write('Masses\n\n')
    for t, (m, el) in MASSES.items():
        f.write(f'{t} {m} # {el}\n')
    f.write('\nAtoms # atomic\n\n')
    for i, (sym, p) in enumerate(zip(fs_all_syms, fs_all_pos), 1):
        f.write(f'{i} {E2T[sym]} {p[0]:.10f} {p[1]:.10f} {p[2]:.10f}\n')
print(f'\nNEB FS raw written : {NEB_FS_RAW}')

# ── Write and submit FS minimization ─────────────────────────
fs_script = write_min_frozen('neb_final', NEB_FS_RAW, FS_RELAXED_DATA)

fs_slurm_lines = [
    '#!/bin/bash',
    '#SBATCH --job-name=nb06_neb_fs',
    f'#SBATCH --ntasks={sc["ntasks"]}',
    f'#SBATCH --cpus-per-task={sc["cpus_per_task"]}',
    f'#SBATCH --gres=gpu:{sc["gpu"]}',
    f'#SBATCH --partition={sc["partition"]}',
    '#SBATCH --time=00:20:00',
    '#SBATCH --output=results/notebook06b-Neb-dissociation/7/slurm_neb_final_%j.out',
    f'module load OpenMPI/{sc["openmpi_ver"]}',
    f'module load cuda/{sc["cuda_version"]}',
    'source ~/miniforge3/etc/profile.d/conda.sh',
    f'conda activate {sc["conda_env"]}',
    ld,
    f'cd {os.getcwd()}',
    f'{LAMMPS_CMD} {kk} -in {fs_script} -log results/notebook06b-Neb-dissociation/7/neb_final_min.log',
    'echo "NEB FS done: $(date)"',
]
fs_slurm_path = 'slurm_scripts/notebook06b-Neb-dissociation/7/run_neb_final.sh'
with open(fs_slurm_path, 'w') as f:
    f.write('\n'.join(fs_slurm_lines) + '\n')
os.chmod(fs_slurm_path, 0o755)

result_fs = subprocess.run(['sbatch', fs_slurm_path], capture_output=True, text=True)
jid_fs = result_fs.stdout.strip().split()[-1] if result_fs.returncode == 0 else 'FAIL'
print(f'FS minimization submitted -> Job {jid_fs}')
print(f'After job finishes (~5 min), run cell 3.5.')
# Out:
# Stripped Velocities from IS
# NEB IS written : structures/notebook06b-Neb-dissociation/7/neb_initial.lammps
# IS site           : ads_top_b.log
# IS H2 center xy   : (1.1716, 6.3396)
# IS H2 height      : +3.3447 A above z_surf
# IS H-H dist       : 0.7617 A
#
# FS site 1 : s_127         xy=(5.2169, 7.3893)  disp=4.5109 A
# FS site 2 : s_143         xy=(1.6293, 7.7649)  disp=1.1947 A
# H-H separation    : 8.8683 A
#
# NEB FS raw written : structures/notebook06b-Neb-dissociation/7/neb_final_raw.lammps
# FS minimization submitted -> Job 7468927
# After job finishes (~5 min), run cell 3.5.

# %% [markdown]
# ### 3.5 — Verify IS and FS
#
# > Run after the FS minimization job finishes.
# > Checks: 362 atoms, H-H molecular in IS, H-H dissociated in FS, delta_E < 0.

# %%
# ─────────────────────────────────────────────────────────────
# Verify IS and FS before running NEB
# IS: H2 molecular (H-H < 1.2 A), above surface
# FS: 2H dissociated (H-H > 2.5 A), dE < 0 (exothermic)
# ─────────────────────────────────────────────────────────────

FS_RELAXED_DATA = 'structures/notebook06b-Neb-dissociation/7/neb_final_relaxed.lammps'
res_fs = parse_energy_log('results/notebook06b-Neb-dissociation/7/neb_final_min.log')

print('IS / FS Verification')
print('=' * 65)

is_ok = False
fs_ok = False
E_FS  = None
delta_E = None

# ── IS ────────────────────────────────────────────────────────
if os.path.exists(NEB_IS_FILE):
    is_atoms     = read(NEB_IS_FILE, format='lammps-data', style='atomic')
    is_pos       = is_atoms.get_positions()
    is_syms      = np.array(is_atoms.get_chemical_symbols())
    h_is         = is_pos[is_syms == 'H']
    hh_is        = np.linalg.norm(h_is[0] - h_is[1])
    z_surf_v     = is_pos[is_syms != 'H', 2].max()
    depth_is     = z_surf_v - h_is[:, 2].mean()
    N_SLAB_ATOMS = len(is_atoms) - 2

    print(f'IS  (H2* at {best_site_log}):')
    print(f'  Atoms        : {len(is_atoms)}  (expect {N_SLAB_ATOMS + 2})')
    print(f'  H-H dist     : {hh_is:.4f} A  (molecular if < 1.2 A)')
    print(f'  H2 depth     : {depth_is:+.4f} A  (negative = above surface)')
    print(f'  Energy       : {E_IS:.6f} eV  [{best_site_log}]')
    is_ok = (len(is_atoms) == N_SLAB_ATOMS + 2 and hh_is < 1.2)
    print(f'  Status       : {"ok" if is_ok else "FAIL"}')
else:
    print('IS file not found — re-run cell 3.4')

print()

# ── FS ────────────────────────────────────────────────────────
if os.path.exists(FS_RELAXED_DATA) and res_fs:
    fs_atoms = read(FS_RELAXED_DATA, format='lammps-data', style='atomic')
    fs_pos   = fs_atoms.get_positions()
    fs_syms  = np.array(fs_atoms.get_chemical_symbols())
    h_fs     = fs_pos[fs_syms == 'H']
    hh_fs    = np.linalg.norm(h_fs[0] - h_fs[1])
    z_surf_v = fs_pos[fs_syms != 'H', 2].max()
    E_FS     = res_fs['pe_final_eV']
    delta_E  = E_FS - E_IS
    cell_v   = fs_atoms.cell.diagonal()

    disps = []
    for hi, hf in zip(h_is, h_fs):
        d = hf - hi
        d -= np.round(d / cell_v) * cell_v
        disps.append(np.linalg.norm(d))

    print(f'FS  (2H* at {best1} + {best2}):')
    print(f'  Atoms        : {len(fs_atoms)}  (expect {N_SLAB_ATOMS + 2})')
    print(f'  H-H dist     : {hh_fs:.4f} A  (dissociated if > 2.5 A)')
    for i, (hf, disp) in enumerate(zip(h_fs, disps)):
        print(f'  H_{i+1} depth   : {z_surf_v - hf[2]:+.4f} A  '
              f'disp from IS = {disp:.4f} A')
    print(f'  Energy       : {E_FS:.6f} eV  [neb_final_min.log]')
    print(f'  delta_E      : {delta_E:.4f} eV  '
          f'({"exothermic — ok" if delta_E < 0 else "endothermic — check FS"})')
    fs_ok = (len(fs_atoms) == N_SLAB_ATOMS + 2 and hh_fs > 2.5 and delta_E < 0)
    print(f'  Status       : {"ok" if fs_ok else "FAIL"}')
else:
    print('FS not ready — wait for neb_final job, then re-run this cell')

print()
print('=' * 65)
print(f'  {"ok" if is_ok else "FAIL"} IS : {N_SLAB_ATOMS + 2} atoms, H-H molecular, above surface')
print(f'  {"ok" if fs_ok else "FAIL"} FS : {N_SLAB_ATOMS + 2} atoms, H-H dissociated, dE < 0')
if is_ok and fs_ok:
    print()
    print(f'  E_IS    = {E_IS:.6f} eV')
    print(f'  E_FS    = {E_FS:.6f} eV')
    print(f'  delta_E = {delta_E:.4f} eV')
    print()
    print('  Both states verified — proceed to cell 3.7')
else:
    print('  Resolve FAIL items before proceeding')
print('=' * 65)
# Out:
# IS / FS Verification
# =================================================================
# IS  (H2* at ads_top_b.log):
#   Atoms        : 362  (expect 362)
#   H-H dist     : 0.7617 A  (molecular if < 1.2 A)
#   H2 depth     : -3.3447 A  (negative = above surface)
#   Energy       : -2398.201099 eV  [ads_top_b.log]
#   Status       : ok
#
# FS  (2H* at s_127 + s_143):
#   Atoms        : 362  (expect 362)
#   H-H dist     : 2.9559 A  (dissociated if > 2.5 A)
#   H_1 depth   : -0.7915 A  disp from IS = 5.0791 A
#   H_2 depth   : -0.5481 A  disp from IS = 2.8206 A
#   Energy       : -2400.432940 eV  [neb_final_min.log]
#   delta_E      : -2.2318 eV  (exothermic — ok)
#   Status       : ok
#
# =================================================================
#   ok IS : 362 atoms, H-H molecular, above surface
#   ok FS : 362 atoms, H-H dissociated, dE < 0
#
#   E_IS    = -2398.201099 eV
#   E_FS    = -2400.432940 eV
#   delta_E = -2.2318 eV
#
#   Both states verified — proceed to cell 3.7
# =================================================================

# %% [markdown]
# ### 3.7 — Write ASE CINEB Script
#
# > Single NEB from IS (H2* physisorbed) to FS (2H* dissociated).
# > Uses IDPP interpolation — avoids atom clashes during dissociation [4].
# > Two-phase: regular NEB (phase 1) then climbing image NEB (phase 2).
# > Runs on 1 A100 GPU, MACECalculator called sequentially.

# %%
# ─────────────────────────────────────────────────────────────
# Write ASE CINEB script — single NEB IS to FS
# IS: H2* at bridge (z_surf+3.57 A, physisorbed)
# FS: 2H* at local hollows flanking bridge (minimized)
# Interpolation: IDPP — avoids atom clashes during dissociation [4]
# Two-phase: regular NEB (phase 1) then CINEB (phase 2)
# ─────────────────────────────────────────────────────────────

sc = SLURM_CONFIG
ld = '\n'.join(f'export LD_LIBRARY_PATH={p}:$LD_LIBRARY_PATH'
               for p in sc['ld_paths'])

FS_RELAXED_DATA = 'structures/notebook06b-Neb-dissociation/7/neb_final_relaxed.lammps'

# Read E_FS from log
res_fs = parse_energy_log('results/notebook06b-Neb-dissociation/7/neb_final_min.log')
if res_fs is None:
    raise FileNotFoundError('neb_final_min.log not found — run cell 3.4 first.')
E_FS = res_fs['pe_final_eV']

# ── Build script lines as a list — no f-string nesting ───────
neb06_py = [
    '#!/usr/bin/env python3',
    f'# ASE CINEB: H2 dissociation on Hastelloy N (111) — Notebook 06',
    f'# IS: H2* at {best_site_log}',
    f'# FS: 2H* at {best1} + {best2}',
    '# Interpolation: IDPP [4] — avoids atom clashes during dissociation',
    '# Two-phase: regular NEB (phase 1) then CINEB (phase 2)',
    '# Refs: NEB [1,2]; CINEB [3]; IDPP [4]; MACE [7]',
    '',
    'import os, sys, numpy as np, torch',
    'from ase.io import read',
    'from ase.mep import NEB',
    'from ase.optimize import MDMin',
    'from ase.calculators.singlepoint import SinglePointCalculator',
    'from mace.calculators import MACECalculator',
    '',
    '# Strip CUDA stubs from LD path — causes segfault on some nodes',
    '_ld = os.environ.get("LD_LIBRARY_PATH", "")',
    'os.environ["LD_LIBRARY_PATH"] = ":".join(',
    '    p for p in _ld.split(":") if "stubs" not in p)',
    '',
    '# ── Paths and parameters injected from notebook ──────────',
    f'MACE_MODEL      = "{MACE_MODEL_ASE}"',
    f'NEB_IS_FILE     = "{NEB_IS_FILE}"',
    f'FS_RELAXED_DATA = "{FS_RELAXED_DATA}"',
    f'Z_FREEZE_CUTOFF = {Z_FREEZE_CUTOFF}  # A — bottom layers frozen',
    f'E_IS            = {E_IS}             # eV — from NB05 minimization',
    f'E_FS            = {E_FS}             # eV — from NB06 FS minimization',
    f'N_IMAGES        = {N_REPLICAS}       # intermediate images',
    f'NEB_FMAX        = {NEB_FTOL}         # eV/A — CINEB convergence',
    f'N1_STEPS        = {N1_STEPS}         # phase 1 steps',
    f'NEB_STEPS       = {NEB_STEPS}        # phase 2 CINEB steps',
    f'SPRING_CONST    = {SPRING_CONST}     # elastic band, to keep image together',
    'N1_FMAX         = NEB_FMAX * 3       # looser fmax for phase 1',
    '',
    'device = "cuda" if torch.cuda.is_available() else "cpu"',
    'print(f"Device: {device}")',
    'sys.stdout.flush()',
    '',
    '# ── Freeze bottom slab layers — H atoms are above cutoff ─',
    'class MACEFrozenCalc(MACECalculator):',
    '    def get_forces(self, atoms=None):',
    '        forces = super().get_forces(atoms).copy()',
    '        a = self.atoms if atoms is None else atoms',
    '        forces[a.get_positions()[:, 2] < Z_FREEZE_CUTOFF] = 0.0',
    '        return forces',
    '',
    'def make_calc():',
    '    """Fresh calculator instance for each intermediate image."""',
    '    return MACEFrozenCalc(',
    '        model_paths=MACE_MODEL,',
    '        device=device,',
    '        default_dtype="float64",',
    '    )',
    '',
    '# ── Load IS and FS structures ─────────────────────────────',
    'print("Loading IS and FS...")',
    'is_raw = read(NEB_IS_FILE,     format="lammps-data", style="atomic")',
    'fs_raw = read(FS_RELAXED_DATA, format="lammps-data", style="atomic")',
    '',
    '# Endpoints use SinglePointCalculator — energies pinned, no re-evaluation',
    'is_end = is_raw.copy()',
    'is_end.calc = SinglePointCalculator(is_end)',
    'is_end.calc.results = {"energy": E_IS, "forces": np.zeros((len(is_end), 3))}',
    '',
    'fs_end = fs_raw.copy()',
    'fs_end.calc = SinglePointCalculator(fs_end)',
    'fs_end.calc.results = {"energy": E_FS, "forces": np.zeros((len(fs_end), 3))}',
    '',
    '# ── Build image chain — intermediates start from IS geometry',
    'images = [is_end]',
    'for _ in range(N_IMAGES):',
    '    img = is_raw.copy()',
    '    img.calc = make_calc()',
    '    images.append(img)',
    'images.append(fs_end)',
    '',
    'print(f"Images: {len(images)} total ({N_IMAGES} intermediate + IS + FS)")',
    'sys.stdout.flush()',
    '',
    '# ── IDPP interpolation — threads H atoms apart above surface',
    'neb = NEB(images, climb=False, k=1.0, method="aseneb")',
    'neb.interpolate(method="idpp")',
    '',
    'print("IDPP interpolation done. H-H distances along path:")',
    'for i, img in enumerate(images):',
    '    lbl = "IS" if i == 0 else ("FS" if i == len(images)-1 else f"img_{i}")',
    '    p = img.get_positions()',
    '    s = np.array(img.get_chemical_symbols())',
    '    h = p[s == "H"]',
    '    hh = np.linalg.norm(h[0]-h[1]) if len(h) == 2 else 0.0',
    '    print(f"  {lbl:6s}: H-H = {hh:.4f} A")',
    'sys.stdout.flush()',
    '',
    '# ── Phase 1: regular NEB — moves images onto MEP ─────────',
    'print(f"\\nPhase 1: regular NEB ({N1_STEPS} steps, fmax={N1_FMAX:.3f} eV/A)")',
    'sys.stdout.flush()',
    'opt1 = MDMin(neb, logfile="results/notebook06b-Neb-dissociation/7/neb06_phase1.log", dt=0.05)',
    'opt1.run(fmax=N1_FMAX, steps=N1_STEPS)',
    # 'print(f"Phase 1 done: {opt1.nsteps} steps")',
    # 'sys.stdout.flush()',
    # '',
    # '# ── Phase 2: CINEB — pushes highest image to saddle point ─',
    # 'neb.climb = True',
    # 'print(f"\\nPhase 2: CINEB ({NEB_STEPS} steps, fmax={NEB_FMAX:.3f} eV/A)")',
    # 'sys.stdout.flush()',
    # 'opt2 = MDMin(neb, logfile="results/notebook06b-Neb-dissociation/7/neb06_phase2.log", dt=0.02)',
    # 'opt2.run(fmax=NEB_FMAX, steps=NEB_STEPS)',
    # 'print(f"Phase 2 done: {opt2.nsteps} steps")',
    # 'sys.stdout.flush()',
    'print(f"Phase 1 done: {opt1.nsteps} steps")',
    'sys.stdout.flush()',
    '',
    '# Reset momenta before CINEB — prevents phase 1 velocity carryover',
    'for img in images[1:-1]:',
    '    img.set_momenta(np.zeros_like(img.get_momenta()))',
    '',
    '# ── Phase 2: CINEB — pushes highest image to saddle point ─',
    'neb.climb = True',
    'print(f"\\nPhase 2: CINEB ({NEB_STEPS} steps, fmax={NEB_FMAX:.3f} eV/A)")',
    'sys.stdout.flush()',
    'opt2 = MDMin(neb, logfile="results/notebook06b-Neb-dissociation/7/neb06_phase2.log", dt=0.02)',
    'try:',
    '    opt2.run(fmax=NEB_FMAX, steps=NEB_STEPS)',
    'except Exception as e:',
    '    print(f"WARNING: phase 2 raised: {e}")',
    '    sys.stdout.flush()',
    'print(f"Phase 2 done: {opt2.nsteps} steps")',
    'sys.stdout.flush()',
    '',
    '# Read true fmax from phase 2 log — avoids NEB-projected force artifact',
    'with open("results/notebook06b-Neb-dissociation/7/neb06_phase2.log", "r") as _f:',
    '    _last = [l for l in _f if l.strip()][-1]',
    'fmax_final = float(_last.split()[-1])',
    'converged  = fmax_final < NEB_FMAX',
    'print(f"fmax from log: {fmax_final:.4f} eV/A  Converged: {converged}")',
    'sys.stdout.flush()',
    '',
    '# ── Extract barrier and reaction energy ───────────────────',
    'energies = []',
    'for img in images:',
    '    try:    energies.append(img.get_potential_energy())',
    '    except: energies.append(None)',
    '',
    'valid   = [e for e in energies if e is not None]',
    'E_a     = max(valid) - E_IS',
    'dE      = E_FS - E_IS',
    '',
    'print(f"\\nNEB06 Results")',
    'print(f"  E_IS     : {E_IS:.6f} eV")',
    'print(f"  E_FS     : {E_FS:.6f} eV")',
    'print(f"  E_a      : {E_a:.4f} eV")',
    'print(f"  delta_E  : {dE:.4f} eV")',
    'print(f"  fmax     : {fmax_final:.4f} eV/A")',
    'print(f"  Converged: {converged}")',
    'sys.stdout.flush()',
    '',
    '# ── Write intermediate image structures ──────────────────',
    'from ase.io import write as ase_write',
    'img_dir = "structures/notebook06b-Neb-dissociation/7/neb_images"',
    'os.makedirs(img_dir, exist_ok=True)',
    '',
    'for i, img in enumerate(images[1:-1], start=1):',
    '    img.info["energy_eV"]  = energies[i]',
    '    img.info["dE_from_IS"] = energies[i] - E_IS',
    '    img.info["image_index"] = i',
    '    fpath = os.path.join(img_dir, f"neb_img_{i:02d}.lammps")',
    '    ase_write(fpath, img, format="lammps-data")',
    '',
    '# Full trajectory (IS + intermediates + FS) for OVITO',
    'traj_path = "results/notebook06b-Neb-dissociation/7/neb_path.extxyz"',
    'ase_write(traj_path, images, format="extxyz")',
    '',
    'print(f"Written {len(images)-2} intermediate structures to {img_dir}")',
    'print(f"Trajectory written to {traj_path}")',
    'sys.stdout.flush()',


    '# ── Write output files ────────────────────────────────────',
    'barrier_file = "results/notebook06b-Neb-dissociation/7/neb_barrier.txt"',
    'path_file    = "results/notebook06b-Neb-dissociation/7/neb_path.dat"',
    '',
    'with open(barrier_file, "w", encoding="utf-8") as f:',
    f'    f.write("IS : H2* at {best_site_log}\\n")',
    f'    f.write("FS : 2H* at {best1} + {best2}\\n")',
    '    f.write("Interpolation: IDPP\\n")',
    '    f.write(f"N images    : {len(images)} ({N_IMAGES} intermediate + IS + FS)\\n")',
    '    f.write(f"fmax_final  : {fmax_final:.4f} eV/A\\n")',
    '    f.write(f"Converged   : {converged}\\n\\n")',
    '    f.write(f"E_IS    = {E_IS:.6f} eV\\n")',
    '    f.write(f"E_FS    = {E_FS:.6f} eV\\n")',
    '    f.write(f"E_a     = {E_a:.4f} eV\\n")',
    '    f.write(f"delta_E = {dE:.4f} eV\\n\\n")',
    '    f.write("Image energies:\\n")',
    '    for i, e in enumerate(energies):',
    '        lbl = "IS" if i == 0 else ("FS" if i == len(energies)-1 else f"img_{i}")',
    '        if e is not None:',
    '            f.write(f"  {lbl:6s}: {e:.6f} eV  ({e-E_IS:+.4f} eV)\\n")',
    '',
    'with open(path_file, "w", encoding="utf-8") as f:',
    '    f.write("# image  E(eV)  dE_from_IS(eV)\\n")',
    '    n = len(energies)',
    '    for i, e in enumerate(energies):',
    '        if e is not None:',
    '            f.write(f"{i/(n-1):.4f}  {e:.6f}  {e-E_IS:+.4f}\\n")',
    '',
    'print("Saved: " + barrier_file)',
    'print("Saved: " + path_file)',
]

neb06_py_path = 'lammps_scripts/notebook06b-Neb-dissociation/7/run_ase_neb06.py'
with open(neb06_py_path, 'w') as f:
    f.write('\n'.join(neb06_py) + '\n')

print(f'Written : {neb06_py_path}')
print(f'  IS    : {NEB_IS_FILE}')
print(f'  FS    : {FS_RELAXED_DATA}')
print(f'  E_IS  : {E_IS:.6f} eV')
print(f'  E_FS  : {E_FS:.6f} eV')
print(f'  Images: {N_REPLICAS} intermediate + IS + FS = {N_REPLICAS+2} total')
print(f'  Interp: IDPP')
print(f'  Phase1: {N1_STEPS} steps, fmax={NEB_FTOL*3:.3f} eV/A')
print(f'  Phase2: {NEB_STEPS} steps, fmax={NEB_FTOL:.3f} eV/A (CINEB)')
print()
print('Run cell 3.8 to submit.')
# Out:
# Written : lammps_scripts/notebook06b-Neb-dissociation/7/run_ase_neb06.py
#   IS    : structures/notebook06b-Neb-dissociation/7/neb_initial.lammps
#   FS    : structures/notebook06b-Neb-dissociation/7/neb_final_relaxed.lammps
#   E_IS  : -2398.201099 eV
#   E_FS  : -2400.432940 eV
#   Images: 18 intermediate + IS + FS = 20 total
#   Interp: IDPP
#   Phase1: 5000 steps, fmax=0.150 eV/A
#   Phase2: 10000 steps, fmax=0.050 eV/A (CINEB)
#
# Run cell 3.8 to submit.

# %% [markdown]
# ### 3.8 — Submit NEB Job
#
# > 1 A100 GPU, ~1-2 hours. After job finishes, run cell 3.9.

# %%
# ─────────────────────────────────────────────────────────────
# Submit ASE CINEB job — 1 A100, sequential force calls
# ─────────────────────────────────────────────────────────────

sc = SLURM_CONFIG
ld = '\n'.join(f'export LD_LIBRARY_PATH={p}:$LD_LIBRARY_PATH'
               for p in sc['ld_paths'])

neb06_slurm = f"""#!/bin/bash
#SBATCH --job-name=nb06_neb
#SBATCH --ntasks=1
#SBATCH --cpus-per-task={sc['cpus_per_task']}
#SBATCH --gres=gpu:a100:1
#SBATCH --partition={sc['partition']}
#SBATCH --output=results/notebook06b-Neb-dissociation/7/slurm_neb06_%j.out

module load OpenMPI/{sc['openmpi_ver']}
module load cuda/{sc['cuda_version']}
source ~/miniforge3/etc/profile.d/conda.sh
conda activate {sc['conda_env']}
{ld}
cd {os.getcwd()}

echo "Node: $(hostname)  Start: $(date)"
python {neb06_py_path}
echo "End: $(date)"
"""

neb06_slurm_path = 'slurm_scripts/notebook06b-Neb-dissociation/7/run_neb06.sh'
with open(neb06_slurm_path, 'w') as f:
    f.write(neb06_slurm)
os.chmod(neb06_slurm_path, 0o755)

result = subprocess.run(['sbatch', neb06_slurm_path],
                        capture_output=True, text=True)
if result.returncode == 0:
    jid = result.stdout.strip().split()[-1]
    print(f'NEB06 submitted -> Job {jid}')
    print(f'Monitor : tail -f results/notebook06b-Neb-dissociation/7/slurm_neb06_{jid}.out')
    print(f'Expected: ~1-2 hours on 1 A100')
else:
    print(f'Submission failed: {result.stderr.strip()}')
# Out:
# NEB06 submitted -> Job 7469490
# Monitor : tail -f results/notebook06b-Neb-dissociation/7/slurm_neb06_7469490.out
# Expected: ~1-2 hours on 1 A100

# %% [markdown]
# ### 3.9 — Parse NEB Results

# %%
# ─────────────────────────────────────────────────────────────
# Parse NEB06 results from barrier file and path file
# Written by run_ase_neb06.py after job completes
# ─────────────────────────────────────────────────────────────

BARRIER_FILE  = 'results/notebook06b-Neb-dissociation/7/neb_barrier.txt'
PATH_FILE     = 'results/notebook06b-Neb-dissociation/7/neb_path.dat'

def parse_barrier_file(path):
    """Parse both = and : delimited lines from barrier txt file."""
    d = {}
    if not os.path.exists(path):
        return None
    with open(path, encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith('#'):
                continue
            if '=' in line:
                k, _, v = line.partition('=')
                try:
                    d[k.strip()] = float(v.strip().split()[0])
                except ValueError:
                    pass
            if ':' in line:
                k, _, v = line.partition(':')
                k = k.strip()
                if k in ('fmax_final', 'Converged', 'N images', 'Interpolation'):
                    d[k] = v.strip()
    return d if d else None

def parse_neb_path(path_file):
    if not os.path.exists(path_file):
        return None
    data = []
    with open(path_file) as f:
        for line in f:
            line = line.strip()
            if line.startswith('#') or not line:
                continue
            try:
                data.append([float(x) for x in line.split()])
            except:
                pass
    return np.array(data) if data else None

barrier       = parse_barrier_file(BARRIER_FILE)
neb_path_data = parse_neb_path(PATH_FILE)

print('NEB06 Results')
print('=' * 60)

if barrier is None:
    print('neb_barrier.txt not found — job may still be running')
    print('Monitor: tail -f results/notebook06b-Neb-dissociation/7/slurm_neb06_*.out')
else:
    E_a       = barrier.get('E_a')
    delta_E   = barrier.get('delta_E')
    E_FS      = barrier.get('E_FS')
    fmax_str  = barrier.get('fmax_final', 'unknown')
    converged = barrier.get('Converged',  'unknown')

    print(f'  E_IS        : {E_IS:.6f} eV')
    print(f'  E_FS        : {E_FS:.6f} eV')
    print(f'  E_a         : {E_a:.4f} eV')
    print(f'  delta_E     : {delta_E:.4f} eV  '
          f'({"exothermic" if delta_E < 0 else "endothermic"})')
    print(f'  fmax_final  : {fmax_str}')
    print(f'  Converged   : {converged}')
    print()

    if E_a < 0.1:
        print('  → H2 dissociates near-barrierlessly at 300 K')
    elif E_a < 0.5:
        print('  → Small barrier — dissociation occurs readily at 300 K')
    elif E_a < 1.0:
        print('  → Moderate barrier — dissociation is rate-limited')
    else:
        print('  → Large barrier — check path for unphysical geometries')
    print()

if neb_path_data is not None:
    print(f'  Path: {len(neb_path_data)} images loaded from {PATH_FILE}')
else:
    print('  Path data not found — available after job completes')

print('=' * 60)
# Out:
# NEB06 Results
# ============================================================
#   E_IS        : -2398.201099 eV
#   E_FS        : -2400.432940 eV
#   E_a         : 0.0000 eV
#   delta_E     : -2.2318 eV  (exothermic)
#   fmax_final  : 0.0498 eV/A
#   Converged   : True
#
#   → H2 dissociates near-barrierlessly at 300 K
#
#   Path: 20 images loaded from results/notebook06b-Neb-dissociation/7/neb_path.dat
# ============================================================

# %% [markdown]
# ### 3.10 — Plot MEP

# %%
# ─────────────────────────────────────────────────────────────
# Plot minimum energy path (MEP)
# ─────────────────────────────────────────────────────────────

if neb_path_data is None or len(neb_path_data) == 0:
    print('neb_path.dat not found — run NEB job first.')
else:
    rxn_coord = neb_path_data[:, 0]   # image fraction 0->1
    e_rel     = neb_path_data[:, 2]   # dE from IS in eV
    ts_idx    = int(np.argmax(e_rel))

    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot(rxn_coord, e_rel, 'o-', color='steelblue',
            lw=2, ms=9, mfc='white', mew=2.5, zorder=3)
    ax.axhline(0, color='gray', ls='--', lw=0.8, alpha=0.5)

    ax.scatter([rxn_coord[0]], [e_rel[0]], s=140,
               color='green', zorder=5,
               label=f'IS: H2* bridge ({e_rel[0]:.3f} eV)')
    ax.scatter([rxn_coord[ts_idx]], [e_rel[ts_idx]], s=160,
               color='red', marker='^', zorder=5,
               label=f'TS: E_a = {e_rel[ts_idx]:.4f} eV')
    ax.scatter([rxn_coord[-1]], [e_rel[-1]], s=140,
               color='purple', zorder=5,
               label=f'FS: 2H* ({e_rel[-1]:.3f} eV)')

    ax.set_xlabel('Reaction Coordinate', fontsize=12)
    ax.set_ylabel('Energy relative to IS (eV)', fontsize=12)
    ax.set_title('H2 Dissociation MEP — Hastelloy N (111)\n'
                 'ASE CINEB + MACE-MP-0b2 | IDPP interpolation',
                 fontsize=10, fontweight='bold')
    ax.legend(fontsize=10)
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('results/notebook06b-Neb-dissociation/7/fig_mep.png', dpi=150, bbox_inches='tight')
    plt.show()
    print('Saved: results/notebook06b-Neb-dissociation/7/fig_mep.png')
    print()
    print(f'E_a     = {e_rel[ts_idx]:.4f} eV  (TS at image {ts_idx})')
    print(f'delta_E = {e_rel[-1]:.4f} eV')
# Out:
# Saved: results/notebook06b-Neb-dissociation/7/fig_mep.png
#
# E_a     = 0.0000 eV  (TS at image 0)
# delta_E = -2.2318 eV

# %% [markdown]
# ### 3.11 — Decision Cell
#
# All checks must pass before proceeding to NB07.

# %%
# ─────────────────────────────────────────────────────────────
# Notebook 06 — Final Decision
# ─────────────────────────────────────────────────────────────

print('=' * 62)
print('  NOTEBOOK 06b — FINAL DECISION')
print('=' * 62)

E_a_final  = barrier.get('E_a')     if barrier else None
dE_final   = barrier.get('delta_E') if barrier else None
E_FS_final = barrier.get('E_FS')    if barrier else None

checks = [
    ('IS file exists',
     os.path.exists(NEB_IS_FILE)),
    ('FS relaxed file exists',
     os.path.exists('structures/notebook06b-Neb-dissociation/7/neb_final_relaxed.lammps')),
    ('NEB barrier file written',
     os.path.exists(BARRIER_FILE)),
    ('NEB path file written',
     os.path.exists(PATH_FILE)),
    ('E_a extracted',
     E_a_final is not None),
    ('E_a physical (0 to 2 eV)',
     E_a_final is not None and 0.0 <= E_a_final <= 2.0),
    ('delta_E negative (exothermic)',
     dE_final is not None and dE_final < 0),
    ('MEP plot saved',
     os.path.exists('results/notebook06b-Neb-dissociation/7/fig_mep.png')),
]

all_pass = True
for label, ok in checks:
    print(f'  {"ok" if ok else "FAIL"} {label}')
    if not ok:
        all_pass = False

print()
if all_pass:
    print('  ALL CHECKS PASSED')
    print()
    print(f'  IS              : H2* at bridge (physisorbed, z_surf+3.57 A)')
    print(f'  FS              : 2H* at local hollows flanking bridge')
    print(f'  E_IS            : {E_IS:.6f} eV')
    print(f'  E_FS            : {E_FS_final:.6f} eV')
    print(f'  E_a             : {E_a_final:.4f} eV')
    print(f'  delta_E         : {dE_final:.4f} eV  (exothermic)')
    print()
    print('  Physical interpretation:')
    if E_a_final < 0.1:
        print('  H2 dissociates barrierlessly — surface is highly reactive')
    elif E_a_final < 0.5:
        print('  Small barrier — H2 dissociates readily at 300 K')
    elif E_a_final < 1.0:
        print('  Moderate barrier — dissociation is rate-limited at 300 K')
    print()
    print('  Proceed to Notebook 07 (Surface Coverage)')
else:
    print('  CHECKS FAILED — resolve all FAIL items above')

print('=' * 62)
# Out:
# ==============================================================
#   NOTEBOOK 06b — FINAL DECISION
# ==============================================================
#   ok IS file exists
#   ok FS relaxed file exists
#   ok NEB barrier file written
#   ok NEB path file written
#   ok E_a extracted
#   ok E_a physical (0 to 2 eV)
#   ok delta_E negative (exothermic)
#   ok MEP plot saved
#
#   ALL CHECKS PASSED
#
#   IS              : H2* at bridge (physisorbed, z_surf+3.57 A)
#   FS              : 2H* at local hollows flanking bridge
#   E_IS            : -2398.201099 eV
#   E_FS            : -2400.432940 eV
#   E_a             : 0.0000 eV
#   delta_E         : -2.2318 eV  (exothermic)
#
#   Physical interpretation:
#   H2 dissociates barrierlessly — surface is highly reactive
#
#   Proceed to Notebook 07 (Surface Coverage)
# ==============================================================
