# %% [markdown]
# # Import packages and libraries

# %%
import ase
import numpy as np
import matplotlib as plt
import os 
import sys 

print(f'ASE version : {ase.__version__}')
print(f'Numpy : {np.__version__}')
print(f'MatPlotLib : {plt.__version__}')

# Build Structure
from ase import atoms
from ase.build import bulk
from ase.build import make_supercell

# Nearest-Neigbour Analysis
from ase.data import atomic_masses, chemical_symbols
from ase.neighborlist import neighbor_list

# Visualise
from ase.visualize import view

#write and read file
from ase.io import read, write

# Auxilliary
from collections import Counter

# Directory
os.makedirs('structures/bulk_structures', exist_ok=True)
# Out:
# ASE version : 3.27.0
# Numpy : 2.4.3
# MatPlotLib : 3.10.8

# %% [markdown]
# # Build Structure

# %% [markdown]
# ![Material Project Cr2O3 file](/projects/westgroup/akinyemi.az/mace_lammps/MHI_Nickel/Screenshot2026-04-20%at%12.18.29%PM.png)

# %%
atom_name= 'Cr'

# %%
from ase.spacegroup import crystal
import numpy as np

# 1. Define the unit cell based on the JSON parameters
a,b, c = 5.00, 5.00, 13.51
alpha, beta, gamma = 90, 90, 120

# 2. Build the stoichiometric unit cell
# Unlike Hastelloy, we don't start with a pure metal; 
# we start with the specific oxide symmetry (Spacegroup 167)
unit_cell = crystal(
    symbols=[atom_name, 'O'],
    basis=[(1/3, 2/3, 0.016523), (0.635025, 0.968359, 0.916667)],
    spacegroup=167,
    cellpar=[a, b, c, alpha, beta, gamma]
)

# 3. Create the 5x5x5 supercell 
# This replicates the 30-atom unit cell 125 times
supercell = unit_cell * (5, 5, 5)

# 4. Check the results
print(f"Alloy structure: Cr2O3")
print(f"Total atoms: {len(supercell)}") # Result: 3750 atoms
# Out:
# Alloy structure: Cr2O3
# Total atoms: 3750

# %%
view(supercell, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 135.1">
#     <group/>
#   </viewpoint>
#   <transform translation="-12.5 -10.825317547305485 -33.775">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 25.0 0.0 0.0 12.500000000000004 21.65063509461097 0.0 -12.499999999999996 21.65063509461097 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 67.55">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 25.0 0.0 0.0 12.500000000000004 21.65063509461097 0.0 -12.499999999999996 21.65063509461097 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 25.0 0.0 0.0 25.0 0.0 67.55 0.0 0.0 67.55 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="-12.499999999999996 21.65063509461097 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 25.0 0.0 0.0 25.0 0.0 67.55 0.0 0.0 67.55 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="5.366077952354923e-16 2.886751345948129 0.22322572999999998">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="2.5 1.4433756729740645 6.53177427">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 4.726559063333333">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="3.14563190310461e-16 2.886751345948129 11.035107603333334">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="2.5 1.4433756729740643 9.229892396666665">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 2.0284409366666645">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="2.500000000000001 1.4433756729740648 13.28677427">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="7.031412489292659e-16 2.8867513459481295 6.978225729999999">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="2.5905203907920326e-16 2.8867513459481295 4.280107603333333">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 11.481559063333332">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 8.783440936666667">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="2.500000000000001 1.4433756729740645 2.474892396666665">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 0.6 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="0.7542275000000005 4.193117469916476 12.38417117">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="-1.5084599999999992 2.886748459196783 12.38417117">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="0.7542325000000003 1.5803881087311278 12.38417117">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="3.2542325 2.749738910191066 7.88082883">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="3.2542275000000003 0.13700954900571727 7.88082883">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="0.9915400000000005 1.4433785597254105 7.88082883">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="0.7542275000000006 1.306366123968347 3.3775045033333337">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="0.991540000000001 4.330124132170847 3.3775045033333337">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>
#           </shape>
#         </transform>
#         <transform translation="-1.7457674999999988 3.023763781705192 3.3775045033333337">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 0.051 0.051"/>
#             </appearance>
#             <sphere radius="0.66"/>

# %%
import numpy as np

# Total atoms in your 5x5x5 supercell: 3750
magmoms = []

# Logic for AFM ordering
for i, atom in enumerate(supercell):
    if atom.symbol == 'Cr':
        # Alternating +3 and -3 to simulate the AFM ground state
        # This keeps the physics of Cr3+ (3 unpaired electrons)
        if i % 2 == 0:
            magmoms.append(3.0)
        else:
            magmoms.append(-3.0)
    else:
        # Oxygen ions (O2-) have closed shells and 0 magnetization
        magmoms.append(0.0)

supercell.set_initial_magnetic_moments(np.array(magmoms))

# Physics Check:
print(f"Net Magnetization: {sum(supercell.get_initial_magnetic_moments())}") # Should be 0.0
print(f"Absolute Moment per Cr: {abs(supercell.get_initial_magnetic_moments()[0])}") # Should be 3.0
# Out:
# Net Magnetization: 0.0
# Absolute Moment per Cr: 3.0

# %% [markdown]
# ### Write out the pure metal-oxide file

# %%
# For .XYZ file
supercell_xyz_path = f'structures/bulk_structures/{atom_name}_oxide_supercell.xyz'
write(supercell_xyz_path, supercell)

# For .lammps file
MASSES = {
    1: (26.9815, 'Al'),
    2: (10.8110, 'B'),
    3: (12.0110, 'C'),
    4: (51.9961, 'Cr'),
    5: (55.8450, 'Fe'),
    6: (95.9600, 'Mo'),
    7: (58.6934, 'Ni'),
    8: (15.9990, 'O'),   # O inserted here — before H
    9: ( 1.0080, 'H'),
}

elem_to_type = {el: t for t, (m, el) in MASSES.items()}

L    = supercell.cell.lengths()
pos  = supercell.get_positions()
syms = supercell.get_chemical_symbols()

lammps_path = f'structures/bulk_structures/{atom_name}_oxide_supercell.lammps'

with open(lammps_path, 'w') as f:
    f.write('# Pure Ni bulk — written by Notebook 01\n\n')
    f.write(f'{len(supercell)} atoms\n')
    f.write(f'{len(MASSES)} atom types\n\n')
    f.write(f'0.0  {L[0]:.10f}  xlo xhi\n')
    f.write(f'0.0  {L[1]:.10f}  ylo yhi\n')
    f.write(f'0.0  {L[2]:.10f}  zlo zhi\n\n')
    f.write('Masses\n\n')
    for t, (m, el) in MASSES.items():
        f.write(f'{t}  {m}  # {el}\n')
    f.write('\nAtoms # atomic\n\n')
    for i, (sym, p) in enumerate(zip(syms, pos), 1):
        t = elem_to_type[sym]
        f.write(f'{i}  {t}  {p[0]:.10f}  {p[1]:.10f}  {p[2]:.10f}\n')

print(f'Written : {lammps_path}')
print(f'Total atoms : {len(supercell)}')
print(f'All atoms type  — all other types reserved for future use')
# Out:
# Written : structures/bulk_structures/Cr_oxide_supercell.lammps
# Total atoms : 3750
# All atoms type  — all other types reserved for future use
